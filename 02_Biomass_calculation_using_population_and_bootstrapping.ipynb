# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from uncertainties import unumpy as unp
import uncertainties
import seaborn as sb
import matplotlib.cm as cm
import scipy
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import time

from scipy.stats.mstats import gmean

# %% [markdown]
# 1. Read the data

# %%
raw_data = pd.read_excel('data/RawData.xlsx')
#raw_data = raw_data[~raw_data.units.str('trap')]

# %% [markdown]
# 2. Focus on the sites which have complementing data: both population (number of individuals) and biomass

# %%
#correct the std for cases where the std is derived from the full reported range, as half this range
indx = ((raw_data['standard deviation']) == (raw_data['numerical value'])) & ((raw_data['standard deviation']) >0)
raw_data.loc[indx , 'standard deviation'] /= 2

#Correct units for dry weight using a general factor of 0.3
raw_data.loc[:,'norm value'] = raw_data.loc[:,'numerical value']
raw_data.loc[raw_data.units=='mg/m^2 (wet weight)','norm value'] *= 0.3 # = raw_data.loc[raw_data.units=='mg/m^2 (wet weight)','norm value']*0.3 #convert the wet mass to an effective dry mass, by multiplying by 0.3

raw_data.loc[raw_data.units=='mg/m^2 (wet weight)','standard deviation'] *= 0.3 # = raw_data.loc[raw_data.units=='mg/m^2 (wet weight)','standard deviation']*0.3 #convert the wet mass to an effective dry mass, by multiplying by 0.3 - for the std 
raw_data.loc[raw_data['standard deviation'].isna(),'standard deviation'] = 0

#change the convertion ratio for specific groups to be more accurate:
#Petersen & Luxton:
#Collembola - 0.32
#Acari - Cryptostigmata  0.4
#Isoptera - 0.27
#Formicodea - 0.228
#Araneae - 0.43
#Pseudoscorpiones  - 0.224
#Others - 0.3
wet_isopera = pd.concat([raw_data['super-family']=='Isoptera', raw_data.units=='mg/m^2 (wet weight)'], axis=1).all(axis=1)
raw_data.loc[wet_isopera,'norm value']= raw_data.loc[wet_isopera,'numerical value']*0.27 
raw_data.loc[wet_isopera,'standard deviation'] *= 0.27/0.3

wet_acari = pd.concat([raw_data['sub-class']=='Acari', raw_data.units=='mg/m^2 (wet weight)'], axis=1).all(axis=1)
raw_data.loc[wet_acari,'norm value']= raw_data.loc[wet_acari,'numerical value']*0.4 
raw_data.loc[wet_acari,'standard deviation'] *= 0.4/0.3

wet_collembola = pd.concat([raw_data['sub-class']=='Collembola', raw_data.units=='mg/m^2 (wet weight)'], axis=1).all(axis=1)
raw_data.loc[wet_collembola,'norm value']= raw_data.loc[wet_collembola,'numerical value']*0.32
raw_data.loc[wet_collembola,'standard deviation'] *= 0.32/0.3

wet_formicidae = pd.concat([raw_data['family']=='Formicidae', raw_data.units=='mg/m^2 (wet weight)'], axis=1).all(axis=1)
raw_data.loc[wet_formicidae,'norm value']= raw_data.loc[wet_formicidae,'numerical value']*0.228 
raw_data.loc[wet_formicidae,'standard deviation'] *= 0.228/0.3

wet_Araneae = pd.concat([raw_data['order']=='Araneae', raw_data.units=='mg/m^2 (wet weight)'], axis=1).all(axis=1)
raw_data.loc[wet_Araneae,'norm value']= raw_data.loc[wet_Araneae,'numerical value']*0.43
raw_data.loc[wet_Araneae,'standard deviation'] *= 0.43/0.3

wet_Araneae = pd.concat([raw_data['order']=='Araneae', raw_data.units=='mg/m^2 (wet weight)'], axis=1).all(axis=1)
raw_data.loc[wet_Araneae,'norm value']= raw_data.loc[wet_Araneae,'numerical value']*0.43
raw_data.loc[wet_Araneae,'standard deviation'] *= 0.43/0.3

wet_Pseudoscorpion = pd.concat([(raw_data['order']=='Pseudoscorpiones') | (raw_data['order']=='Pseudoscorpionida'), raw_data.units=='mg/m^2 (wet weight)'], axis=1).all(axis=1)
raw_data.loc[wet_Pseudoscorpion,'norm value']= raw_data.loc[wet_Pseudoscorpion,'numerical value']*0.224
raw_data.loc[wet_Pseudoscorpion,'standard deviation'] *= 0.224/0.3



#units type distinguishes population to biomass measurements
def unit_type(x):
    X=x.partition('/')[0]
    return X

raw_data.loc[:,'units type'] = raw_data.units.apply(unit_type) #units type distinguishes population to biomass measurements

raw_data.groupby('units type').site.nunique()#display the counts for the separated data
# Out:
# units type
# individuals    444
# mg             392
# Name: site, dtype: int64

# %% [markdown]
# 3. Remove partial measurements

# %%
metadata = pd.read_csv('data/groups_per_reference.csv')
data_with_meta = raw_data.merge(metadata,left_on='reference', right_on='Paper',how='left')

# %%
valid_data = data_with_meta.copy()
valid_data = valid_data[(valid_data['Standard groups']!='Microarthropods') | ((valid_data['Standard groups']=='Microarthropods') & (valid_data['sub-class'].isin(['Acari','Collembola'])))]#~~~improve

# %% [markdown]
# 4. Classify into groups using "aggregated taxon" and "aggregated environment"

# %%
valid_data.loc[valid_data['sub-class']=='Acari','aggregated taxon'] = 'Acari'
valid_data.loc[valid_data['sub-class']=='Collembola','aggregated taxon'] = 'Collembola'
valid_data.loc[valid_data['super-family']=='Isoptera','aggregated taxon'] = 'Isoptera'
valid_data.loc[valid_data['family']=='Formicidae','aggregated taxon'] = 'Formicidae'
valid_data.loc[valid_data['aggregated taxon'].isna(),'aggregated taxon'] = 'Other'

# %%
soil_data = valid_data[valid_data['aggregated environment'] =='soil/litter']
canopy_data = valid_data[valid_data['aggregated environment'] =='plants']
surface_data = valid_data[valid_data['aggregated environment'] =='above ground']

# %% [markdown]
# 5. Remove measurements with unknown biomes (ants)

# %%
#Drop the ants measurements with unknown biomes
soil_data = soil_data[soil_data['aggregated biome'] != 'Shrubland/Grassland']

# %% [markdown]
# 6. Sum and average over taxa per site, and calculate the effective mass of an individual soil arthropod

# %%
#Average the soil data over each taxon in each site, then sum all taxons in each site according to the aggregated groups and data type they are in.
soil_site_taxa_mean = soil_data.groupby(['units type','aggregated taxon','aggregated biome','site','taxon'])['norm value'].mean().reset_index()
soil_site_data = soil_site_taxa_mean.groupby(['units type','aggregated taxon','aggregated biome','site'])['norm value'].sum().reset_index()

#Divide into the two types of measurements
soil_site_data_pop = soil_site_data[soil_site_data['units type']=='individuals']
soil_site_data_pop.rename(columns={'norm value': 'population density'}, inplace=True)

soil_site_data_mass = soil_site_data[soil_site_data['units type']=='mg']
soil_site_data_mass.rename(columns={'norm value': 'mass density'}, inplace=True)

#Construct a new dataframe, where we keep only the sites with both measurement types
soil_site_data_comb = pd.merge( soil_site_data_pop, soil_site_data_mass, on=["aggregated taxon","aggregated biome","site"], how="inner", validate="one_to_one" )

#calculate the mass of an individual per site, in units of mg/ind
soil_site_data_comb.loc[:,'ind mass']=soil_site_data_comb.loc[:,'mass density']/soil_site_data_comb.loc[:,'population density']

#Present the mass of an individual per biome and taxon, in units of mg/ind
soil_site_data_comb.pivot_table(index='aggregated taxon',columns='aggregated biome',values='ind mass', aggfunc=['mean','count'])
# Out:
# /Users/Yuvalr/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#                                  mean                                        \
# aggregated biome Boreal Forests/Taiga     Crops   Pasture Temperate Forests
# aggregated taxon
# Acari                        0.003871       NaN       NaN          0.017402
# Collembola                   0.004669       NaN       NaN          0.016207
# Formicidae                        NaN  0.261255  0.600161          2.278229
# Isoptera                          NaN  0.737154  0.610434          0.680539
# Other                        0.351622  2.520194  3.820162          3.340000
#
#                                                                 \
# aggregated biome Temperate Grasslands, Savannas and Shrublands
# aggregated taxon
# Acari                                                 0.001764
# Collembola                                            0.002450
# Formicidae                                            0.548186
# Isoptera                                              0.289569
# Other                                                 3.178365
#
#                                                    \
# aggregated biome Tropical and Subtropical Forests
# aggregated taxon
# Acari                                    0.001765
# Collembola                               0.008673
# Formicidae                               0.343055
# Isoptera                                 0.982253
# Other                                    4.056096
#
#                                                                                \
# aggregated biome Tropical and Subtropical Grasslands, Savannas and Shrublands
# aggregated taxon
# Acari                                                      0.002253
# Collembola                                                 0.004211
# Formicidae                                                 0.749205
# Isoptera                                                   1.539741
# Other                                                      3.133116
#
#                                           count                \
# aggregated biome    Tundra Boreal Forests/Taiga Crops Pasture
# aggregated taxon
# Acari             0.005811                 17.0   NaN     NaN
# Collembola        0.006060                 17.0   NaN     NaN
# Formicidae             NaN                  NaN   6.0    10.0
# Isoptera               NaN                  0.0   9.0    16.0
# Other             1.242991                 15.0   7.0    11.0
#
#                                     \
# aggregated biome Temperate Forests
# aggregated taxon
# Acari                         13.0
# Collembola                    13.0
# Formicidae                     5.0
# Isoptera                       3.0
# Other                         14.0
#
#                                                                 \
# aggregated biome Temperate Grasslands, Savannas and Shrublands
# aggregated taxon
# Acari                                                      3.0
# Collembola                                                 7.0
# Formicidae                                                 4.0
# Isoptera                                                   1.0
# Other                                                     11.0
#
#                                                    \
# aggregated biome Tropical and Subtropical Forests
# aggregated taxon
# Acari                                         4.0
# Collembola                                    4.0
# Formicidae                                   10.0
# Isoptera                                     32.0
# Other                                        16.0
#
#                                                                                \
# aggregated biome Tropical and Subtropical Grasslands, Savannas and Shrublands
# aggregated taxon
# Acari                                                           2.0
# Collembola                                                      2.0
# Formicidae                                                      3.0
# Isoptera                                                       11.0
# Other                                                           4.0
#
#
# aggregated biome Tundra
# aggregated taxon
# Acari              48.0
# Collembola         33.0
# Formicidae          NaN
# Isoptera            NaN
# Other              13.0

# %%
#filter out outliers for the effective mass of an individuals
def filter_outliers(x):
    if len(x)>3:
        STD=x.std()
        Mean=np.mean(x)
        x = x[x<(Mean+2*STD)]
        x = x[x>(Mean-2*STD)]
    return x

soil_ratio_filt = soil_site_data_comb.groupby(['aggregated taxon','aggregated biome'])['ind mass'].apply(filter_outliers)
soil_ratio_filt_full = soil_ratio_filt.reset_index().pivot_table(index='aggregated taxon',columns='aggregated biome',values='ind mass', aggfunc='mean')
soil_ratio_filt_total = soil_ratio_filt.reset_index().groupby('aggregated taxon')['ind mass'].mean() #the global mean for the mass ratio per taxon
soil_ratio_filt_full = pd.merge(soil_ratio_filt_full, soil_ratio_filt_total,on="aggregated taxon", how="inner", validate="one_to_one" )
soil_ratio_filt_full.rename(columns={'ind mass': 'Total average (mg/ind)'}, inplace=True)

#fill in the nans with the global averages and save to csv
for clm in soil_ratio_filt_full.columns:
    soil_ratio_filt_full.loc[soil_ratio_filt_full[clm].isnull(),clm] = soil_ratio_filt_full['Total average (mg/ind)']

biomes = soil_site_data_pop.loc[:,'aggregated biome'].unique()

for biom in biomes: 
    if biom not in soil_ratio_filt_full.columns:
        soil_ratio_filt_full.loc[:,biom] = soil_ratio_filt_full.loc[:,'Total average (mg/ind)']
        
soil_ratio_filt_full.to_csv('results/average_ind_mass_full.csv')##       


def print_ratio(x):
    return '{:.2e}'.format(x)

soil_ratio_filt_print = soil_ratio_filt_full.applymap(print_ratio)
#soil_ratio_filt_print.to_csv('results/table_average_ind_mass.csv')## #~~ export rounded values

#~~~can be removed
#soil_ratio_filt_pd = soil_ratio_filt.reset_index().groupby(["aggregated taxon","aggregated biome"]).mean()['ind mass'].reset_index()
#soil_ratio_filt_pd = soil_ratio_filt.reset_index().groupby(["aggregated taxon","aggregated biome"]).mean().drop(columns='level_2')
#soil_ratio_filt_pd.to_csv('results/pd_average_ind_mass.csv')##


#present soil_ratio_filt_print
soil_ratio_filt_full.applymap(print_ratio)
# Out:
#                  Boreal Forests/Taiga     Crops   Pasture Temperate Forests  \
# aggregated taxon
# Acari                        3.87e-03  5.15e-03  5.15e-03          9.99e-03
# Collembola                   4.35e-03  5.68e-03  5.68e-03          9.98e-03
# Formicidae                   6.70e-01  9.75e-02  6.00e-01          2.28e+00
# Isoptera                     7.08e-01  7.37e-01  5.60e-01          6.81e-01
# Other                        3.09e-01  2.52e+00  3.82e+00          1.56e+00
#
#                  Temperate Grasslands, Savannas and Shrublands  \
# aggregated taxon
# Acari                                                 1.76e-03
# Collembola                                            2.45e-03
# Formicidae                                            5.48e-01
# Isoptera                                              2.90e-01
# Other                                                 2.37e+00
#
#                  Tropical and Subtropical Forests  \
# aggregated taxon
# Acari                                    1.77e-03
# Collembola                               8.67e-03
# Formicidae                               2.00e-01
# Isoptera                                 7.38e-01
# Other                                    2.63e+00
#
#                  Tropical and Subtropical Grasslands, Savannas and Shrublands  \
# aggregated taxon
# Acari                                                      2.25e-03
# Collembola                                                 4.21e-03
# Formicidae                                                 7.49e-01
# Isoptera                                                   8.67e-01
# Other                                                      3.13e+00
#
#                     Tundra Total average (mg/ind)  \
# aggregated taxon
# Acari             5.00e-03               5.15e-03
# Collembola        5.13e-03               5.68e-03
# Formicidae        6.70e-01               6.70e-01
# Isoptera          7.08e-01               7.08e-01
# Other             2.87e-01               1.89e+00
#
#                  Deserts and Xeric Shrublands  \
# aggregated taxon
# Acari                                5.15e-03
# Collembola                           5.68e-03
# Formicidae                           6.70e-01
# Isoptera                             7.08e-01
# Other                                1.89e+00
#
#                  Mediterranean Forests, Woodlands and Scrub
# aggregated taxon
# Acari                                              5.15e-03
# Collembola                                         5.68e-03
# Formicidae                                         6.70e-01
# Isoptera                                           7.08e-01
# Other                                              1.89e+00

# %%
#find the measurements where only population data is available
cond1 = soil_site_data_pop['site'].isin(soil_site_data_comb['site'])
cond2 = soil_site_data_pop['population density'].isin(soil_site_data_comb['population density'])
soil_site_data_pop_pure = soil_site_data_pop.drop(soil_site_data_pop[cond1 & cond2].index )#measurements with only population measurements, and no mass measurements, based on site name and numerical value

# %%
#convert population to effective mass
soil_site_data_pop_pure.loc[:,'eff. mass_B'] = np.nan # eff. mass_B will use taxon and biome level average mass of individual
soil_site_data_pop_pure.loc[:,'eff. mass_G'] = np.nan # eff. mass_G will use global average for each taxon
for ii in soil_site_data_pop_pure.index:
    if soil_site_data_pop_pure.loc[ii,'aggregated taxon'] != 'Other':
        soil_site_data_pop_pure.loc[ii,'eff. mass_B'] = soil_site_data_pop_pure.loc[ii,'population density']* soil_ratio_filt_full.loc[soil_site_data_pop_pure.loc[ii,'aggregated taxon'],soil_site_data_pop_pure.loc[ii,'aggregated biome']]
        soil_site_data_pop_pure.loc[ii,'eff. mass_G'] = soil_site_data_pop_pure.loc[ii,'population density']* soil_ratio_filt_full.loc[soil_site_data_pop_pure.loc[ii,'aggregated taxon'],'Total average (mg/ind)']

#merge all the measurements, converted into biomass
soil_site_data_mass_all = pd.merge(soil_site_data_mass,soil_site_data_pop_pure,on=["aggregated taxon","aggregated biome","site"], how="outer")
indx_mass = ~np.isnan(soil_site_data_mass_all.loc[:,'mass density']) #index of the mass measurements

#mass_B/G columns are a combination of the measured mass with the effective mass where no direct measurement is given (_B and _G are for biome level or global level)
soil_site_data_mass_all.loc[:,'mass_B'] = np.nan
soil_site_data_mass_all.loc[:,'mass_G'] = np.nan
soil_site_data_mass_all.loc[indx_mass,'mass_B'] = soil_site_data_mass_all.loc[indx_mass,'mass density']
soil_site_data_mass_all.loc[~indx_mass,'mass_B'] = soil_site_data_mass_all.loc[~indx_mass,'eff. mass_B']
soil_site_data_mass_all.loc[indx_mass,'mass_G'] = soil_site_data_mass_all.loc[indx_mass,'mass density']
soil_site_data_mass_all.loc[~indx_mass,'mass_G'] = soil_site_data_mass_all.loc[~indx_mass,'eff. mass_G']

soil_site_data_mass_all = soil_site_data_mass_all[~np.isnan(soil_site_data_mass_all.loc[:,'mass_G'])] # remove measurements of "other" taxa, and where there is no direct biomass measurement
#indx_pop_other = np.isnan(soil_site_data_mass_all.loc[:,'mass_G']) #index of measurements of "other" taxa, and where there is no direct biomass measurement

#soil_site_data_mass_all.groupby(["aggregated biome","aggregated taxon"]).count()

# %% [markdown]
# 6.1 Repeat the analysis, but for the std

# %%
#Average the soil data std over each taxon in each site, then sum all taxons std in each site according to the aggregated groups and data type they are in.

def sum_error(x):
    return np.sqrt(np.sum(x**2))

def mean_error(x):
    return sum_error(x)/np.sqrt(len(x))

soil_site_taxa_mean_std = soil_data.groupby(['units type','aggregated taxon','aggregated biome','site','taxon'])['standard deviation'].apply(mean_error).reset_index()
soil_site_data_std = soil_site_taxa_mean_std.groupby(['units type','aggregated taxon','aggregated biome','site'])['standard deviation'].apply(sum_error).reset_index()


#Divide into the two types of measurements
soil_site_data_pop_std = soil_site_data_std[soil_site_data_std['units type']=='individuals']
soil_site_data_pop_std.rename(columns={'standard deviation': 'pop_std'}, inplace=True)

soil_site_data_mass_std = soil_site_data_std[soil_site_data_std['units type']=='mg']
soil_site_data_mass_std.rename(columns={'standard deviation': 'mass_std'}, inplace=True)

#Construct a new dataframe, where we keep only the sites with both measurement types
soil_site_data_comb_std = pd.merge( soil_site_data_pop_std, soil_site_data_mass_std, on=["aggregated taxon","aggregated biome","site"], how="inner", validate="one_to_one" )

#measurements with only population measurements, and no mass measurements, based on site name and numerical value
soil_site_data_pop_pure_std = soil_site_data_pop_std.drop(soil_site_data_pop_std[cond1 & cond2].index )


#convert population to effective mass
soil_site_data_pop_pure_std.loc[:,'eff. mass_B'] = np.nan # eff. mass_B will use taxon and biome level average mass of individual
soil_site_data_pop_pure_std.loc[:,'eff. mass_G'] = np.nan # eff. mass_G will use global average for each taxon
for ii in soil_site_data_pop_pure_std.index:
    if soil_site_data_pop_pure_std.loc[ii,'aggregated taxon'] != 'Other':
        soil_site_data_pop_pure_std.loc[ii,'eff. mass_B'] = soil_site_data_pop_pure_std.loc[ii,'pop_std']* soil_ratio_filt_full.loc[soil_site_data_pop_pure.loc[ii,'aggregated taxon'],soil_site_data_pop_pure.loc[ii,'aggregated biome']]
        soil_site_data_pop_pure_std.loc[ii,'eff. mass_G'] = soil_site_data_pop_pure_std.loc[ii,'pop_std']* soil_ratio_filt_full.loc[soil_site_data_pop_pure.loc[ii,'aggregated taxon'],'Total average (mg/ind)']

#Merge all the measurements, converted into mass
soil_site_data_mass_all_std = pd.merge(soil_site_data_mass_std,soil_site_data_pop_pure_std,on=["aggregated taxon","aggregated biome","site"], how="outer")

indx_mass = ~np.isnan(soil_site_data_mass_all_std.loc[:,'mass_std']) #index of the mass measurements

soil_site_data_mass_all_std.loc[:,'mass_B'] = np.nan
soil_site_data_mass_all_std.loc[:,'mass_G'] = np.nan
soil_site_data_mass_all_std.loc[indx_mass,'mass_B'] = soil_site_data_mass_all_std.loc[indx_mass,'mass_std']
soil_site_data_mass_all_std.loc[~indx_mass,'mass_B'] = soil_site_data_mass_all_std.loc[~indx_mass,'eff. mass_B']
soil_site_data_mass_all_std.loc[indx_mass,'mass_G'] = soil_site_data_mass_all_std.loc[indx_mass,'mass_std']
soil_site_data_mass_all_std.loc[~indx_mass,'mass_G'] = soil_site_data_mass_all_std.loc[~indx_mass,'eff. mass_G']

soil_site_data_mass_all_std = soil_site_data_mass_all_std[~np.isnan(soil_site_data_mass_all_std.loc[:,'mass_G'])] # remove measurements of "other" taxa, and where there is no direct biomass measurement
#indx_pop_other = np.isnan(soil_site_data_mass_all.loc[:,'mass_G']) #index of measurements of "other" taxa, and where there is no direct biomass measurement

#soil_site_data_mass_all.groupby(["aggregated biome","aggregated taxon"]).count()

# %% [markdown]
# 7. Take the mean in various ways

# %%
def Mean_alt(x , kk = 1 , scale = 1): #returns the arithmetic mean, lower, and upper standard errors based on a log transform with a shift parameter kk (default = 1). Scale changes the units used, such that the effect of kk can be reduced (see Finney 1941)
    if kk == 0 or len(x) < 3:
        return  np.mean(x), np.min(x), np.max(x)
    else:    
        Xlog = np.log(scale*x + kk) ### 
        Xm = np.mean(Xlog)
        s2 = np.var(Xlog)
        s4 = s2**2
        n = len(Xlog)
        Mean = (( np.exp(Xm+0.5*s2)*(1-(s2*(s2+2)/(4*n)) + s4*(3*s4+44*s2+84)/(96*n**2)))-kk)/scale
        Var = s2/n + s4/(2*(n-1))
        Low = Xm+0.5*s2 - 1.96*np.sqrt(Var)
        High = Xm+0.5*s2 + 1.96*np.sqrt(Var)
        return Mean, (np.exp(Low)-kk)/scale, (np.exp(High)-kk)/scale


#Bootstrap using random choose with replacement. returns an array of means
def Boot_means(vals, sigma,Boot_N):
    L = len(vals)
    means = np.zeros(Boot_N) 

    for ii in range(Boot_N): #random choose with replacement
        indx = rng.choice(np.array(range(L)),L, replace=True)

        Boot = np.zeros(L)
        jj=0
        for ind in indx: #add the measurement uncertainties using a normal distribution
            Boot[jj] = np.max( [ 0 , rng.normal(vals[ind], sigma[ind], 1) ])
            jj +=1
        
        means[ii] = np.mean(Boot) #take the mean of a single resample
    
    return means
    
#Extract mean and 95% CI from bootstrapped data (returns an array)
def Boot_stats(means, prcnt_low=2.5, prcnt_high=97.5):    
    Mean = np.mean(means)
    prcnt = np.percentile(means,[prcnt_low,prcnt_high])
    return np.array([Mean , prcnt[0], prcnt[1]])


rng = np.random.default_rng()

# %%
def LogMean(x , kk = 1 , scale = 1): #returns the geometric mean, lower, and upper standard errors based on a log transform with a shift parameter kk (default = 1). Scale changes the units used, such that the effect of kk can be changed
    if kk == 0 or len(x) < 2:
        return  gmean(x), 0 , 0
    else:    
        Xlog = np.log10(scale*x + kk)                
        return ((10**np.mean(Xlog))-kk)/scale , ((10**(np.mean(Xlog)-Xlog.sem()))-kk)/scale ,((10**(np.mean(Xlog)+Xlog.sem()))-kk)/scale
    
def calc_uval(x):
    return unp.uarray(nominal_values=np.mean(x),std_devs=x.sem())

Scale = 1e1 #such that "kk=1" corresponds to 0.1mg, which is the "detection limit"
    

def calc_mean(x):
    return (LogMean(x,kk = 1,scale = Scale)[0]+np.mean(x))/2

def calc_min(x):    
    return np.nanmin( np.array([LogMean(x,kk = 1,scale = Scale)[0], np.mean(x)-x.sem()]) )
    
def calc_max(x):
    return np.nanmax( np.array([LogMean(x,kk = 1,scale = Scale)[2], np.mean(x)+x.sem(), np.mean(x)]) )

def calc_mean_log(x):
    return LogMean(x,kk = 1,scale = Scale)[0]

def calc_mean_ar(x):
    return np.mean(x)

def calc_mean_ar_sem(x):
    return x.sem()

###
def calc_mean_alt(x):
    return Mean_alt(x,kk = 1,scale = Scale)[0]

def calc_min_alt(x):    
    return Mean_alt(x,kk = 1,scale = Scale)[1]
    
def calc_max_alt(x):
    return Mean_alt(x,kk = 1,scale = Scale)[2]
###


#make DF with various means using global or biome level effective mass
soil_biome_means_B = soil_site_data_mass_all.reset_index().groupby(['aggregated taxon','aggregated biome'])['mass_B'].agg([calc_mean,calc_min,calc_max,calc_mean_log,calc_mean_ar,calc_mean_ar_sem,'count'])
soil_biome_means_G = soil_site_data_mass_all.reset_index().groupby(['aggregated taxon','aggregated biome'])['mass_G'].agg([calc_mean,calc_min,calc_max,calc_mean_log,calc_mean_ar,calc_mean_ar_sem,'count'])
soil_biome_means_B.rename(columns={'calc_mean': 'Mean', 'calc_min': 'Min', 'calc_max': 'Max', 'calc_mean_log': 'Mean_Log', 'calc_mean_ar': 'Mean_Ar','calc_mean_ar_sem': 'Sem_Ar', 'count': 'N'}, inplace=True)
soil_biome_means_G.rename(columns={'calc_mean': 'Mean', 'calc_min': 'Min', 'calc_max': 'Max', 'calc_mean_log': 'Mean_Log', 'calc_mean_ar': 'Mean_Ar','calc_mean_ar_sem': 'Sem_Ar', 'count': 'N'}, inplace=True)

##Make a copy in pivot tables that will be exported
#soil_biome_means_print1 = soil_site_data.reset_index().pivot_table(index='aggregated taxon',columns='aggregated biome',values='numerical value', aggfunc=[calc_mean,'count'])
#soil_biome_means_print2 = soil_site_data.reset_index().pivot_table(index='aggregated taxon',columns='aggregated biome',values='numerical value', aggfunc=[calc_uval,calc_mean_log,'count'])

#soil_biome_means_print1 = soil_biome_means_print1.unstack().reset_index().pivot_table(index='aggregated taxon', columns=['aggregated biome','level_0'],values=0,aggfunc=sum)
#soil_biome_means_print1.columns = soil_biome_means_print1.columns.set_levels(['Mean','N'],1)
#soil_biome_means_print2 = soil_biome_means_print2.unstack().reset_index().pivot_table(index='aggregated taxon', columns=['aggregated biome','level_0'],values=0,aggfunc=sum)
#soil_biome_means_print2.columns = soil_biome_means_print2.columns.set_levels(['G.Mean','A.Mean','N'],1)

#def print_u(x):
#    if type(x) != uncertainties.core.Variable:
#        if x<1000:
#            return '{:.0f}'.format(x)
#        else:
#            return '{:.2e}'.format(x)
#    else: 
#        return '{:.2e}'.format(x.nominal_value)+'±'+'{:.0f}'.format(x.std_dev)

#soil_biome_means_print1 = soil_biome_means_print1.applymap(print_u)
#soil_biome_means_print2 = soil_biome_means_print2.applymap(print_u)
#soil_biome_means_print_full = soil_biome_means.applymap(print_u)

##save to .csv files
#soil_biome_means_print1.to_csv('results/table_1pop.csv')
#soil_biome_means_print2.to_csv('results/table_1pop_means.csv')
#soil_biome_means_print_full.to_csv('results/table_1pop_full.csv')
# Out:
# /Users/Yuvalr/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:324: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(np.array(a, dtype=dtype))

# %%
soil_biome_means_G
# Out:
#                                                                             Mean  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                 362.103242
#                  Crops                                                 80.639406
#                  Deserts and Xeric Shrublands                           3.193516
#                  Mediterranean Forests, Woodlands and Scrub            42.182567
#                  Pasture                                               17.802833
#                  Temperate Forests                                    604.172230
#                  Temperate Grasslands, Savannas and Shrublands        199.569514
#                  Tropical and Subtropical Forests                     155.292725
#                  Tropical and Subtropical Grasslands, Savannas a...    65.529637
#                  Tundra                                               168.223164
# Collembola       Boreal Forests/Taiga                                 302.641661
#                  Crops                                                 23.387343
#                  Deserts and Xeric Shrublands                           0.846665
#                  Mediterranean Forests, Woodlands and Scrub            36.064455
#                  Pasture                                                1.526924
#                  Temperate Forests                                    201.934157
#                  Temperate Grasslands, Savannas and Shrublands        134.400127
#                  Tropical and Subtropical Forests                      40.610627
#                  Tropical and Subtropical Grasslands, Savannas a...    12.330908
#                  Tundra                                               263.477422
# Formicidae       Boreal Forests/Taiga                                   4.414694
#                  Crops                                                 44.594341
#                  Deserts and Xeric Shrublands                          41.396991
#                  Mediterranean Forests, Woodlands and Scrub            39.000000
#                  Pasture                                              119.001172
#                  Temperate Forests                                    388.832971
#                  Temperate Grasslands, Savannas and Shrublands        208.632625
#                  Tropical and Subtropical Forests                     134.602837
#                  Tropical and Subtropical Grasslands, Savannas a...   601.415818
#                  Tundra                                                 0.000000
# Isoptera         Boreal Forests/Taiga                                   0.000000
#                  Crops                                                960.697608
#                  Deserts and Xeric Shrublands                          41.073826
#                  Mediterranean Forests, Woodlands and Scrub           411.235798
#                  Pasture                                              438.314960
#                  Temperate Forests                                    194.987924
#                  Temperate Grasslands, Savannas and Shrublands        366.775379
#                  Tropical and Subtropical Forests                    1164.277828
#                  Tropical and Subtropical Grasslands, Savannas a...   790.304754
#                  Tundra                                                 0.000000
# Other            Boreal Forests/Taiga                                 184.016320
#                  Crops                                                893.508026
#                  Pasture                                              434.052806
#                  Temperate Forests                                    873.402560
#                  Temperate Grasslands, Savannas and Shrublands        540.959396
#                  Tropical and Subtropical Forests                     426.272099
#                  Tropical and Subtropical Grasslands, Savannas a...   134.864932
#                  Tundra                                                43.085600
#
#                                                                             Min  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                291.142690
#                  Crops                                                57.630928
#                  Deserts and Xeric Shrublands                          2.045361
#                  Mediterranean Forests, Woodlands and Scrub            6.610139
#                  Pasture                                               2.031131
#                  Temperate Forests                                   350.418631
#                  Temperate Grasslands, Savannas and Shrublands       113.979553
#                  Tropical and Subtropical Forests                    126.006528
#                  Tropical and Subtropical Grasslands, Savannas a...   26.626772
#                  Tundra                                              114.600949
# Collembola       Boreal Forests/Taiga                                136.848532
#                  Crops                                                16.933596
#                  Deserts and Xeric Shrublands                          0.497411
#                  Mediterranean Forests, Woodlands and Scrub           28.884714
#                  Pasture                                               0.002735
#                  Temperate Forests                                   111.827618
#                  Temperate Grasslands, Savannas and Shrublands        82.978605
#                  Tropical and Subtropical Forests                     33.311441
#                  Tropical and Subtropical Grasslands, Savannas a...   11.372101
#                  Tundra                                              126.766659
# Formicidae       Boreal Forests/Taiga                                  1.541285
#                  Crops                                                25.071996
#                  Deserts and Xeric Shrublands                         24.412431
#                  Mediterranean Forests, Woodlands and Scrub           39.000000
#                  Pasture                                             102.892558
#                  Temperate Forests                                    60.625943
#                  Temperate Grasslands, Savannas and Shrublands        75.309807
#                  Tropical and Subtropical Forests                     61.147680
#                  Tropical and Subtropical Grasslands, Savannas a...  504.090979
#                  Tundra                                                0.000000
# Isoptera         Boreal Forests/Taiga                                  0.000000
#                  Crops                                               488.549306
#                  Deserts and Xeric Shrublands                          1.783265
#                  Mediterranean Forests, Woodlands and Scrub          243.271596
#                  Pasture                                              80.084077
#                  Temperate Forests                                    20.892514
#                  Temperate Grasslands, Savannas and Shrublands         0.600000
#                  Tropical and Subtropical Forests                    474.988054
#                  Tropical and Subtropical Grasslands, Savannas a...  458.918895
#                  Tundra                                                0.000000
# Other            Boreal Forests/Taiga                                 98.523566
#                  Crops                                               655.954940
#                  Pasture                                             199.967486
#                  Temperate Forests                                   681.339831
#                  Temperate Grasslands, Savannas and Shrublands       272.748943
#                  Tropical and Subtropical Forests                    146.958944
#                  Tropical and Subtropical Grasslands, Savannas a...   64.174916
#                  Tundra                                               21.849101
#
#                                                                              Max  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                 505.295990
#                  Crops                                                134.159189
#                  Deserts and Xeric Shrublands                           5.761297
#                  Mediterranean Forests, Woodlands and Scrub           121.333775
#                  Pasture                                               59.611209
#                  Temperate Forests                                   1048.051500
#                  Temperate Grasslands, Savannas and Shrublands        355.882104
#                  Tropical and Subtropical Forests                     237.946262
#                  Tropical and Subtropical Grasslands, Savannas a...   121.618925
#                  Tundra                                               265.452498
# Collembola       Boreal Forests/Taiga                                 733.422026
#                  Crops                                                 33.090188
#                  Deserts and Xeric Shrublands                           1.880495
#                  Mediterranean Forests, Woodlands and Scrub            55.656928
#                  Pasture                                                5.924351
#                  Temperate Forests                                    381.290130
#                  Temperate Grasslands, Savannas and Shrublands        231.444254
#                  Tropical and Subtropical Forests                      58.967669
#                  Tropical and Subtropical Grasslands, Savannas a...    13.328191
#                  Tundra                                               531.452546
# Formicidae       Boreal Forests/Taiga                                   8.711609
#                  Crops                                                 85.872630
#                  Deserts and Xeric Shrublands                          90.301316
#                  Mediterranean Forests, Woodlands and Scrub            39.000000
#                  Pasture                                              164.699618
#                  Temperate Forests                                   1346.093945
#                  Temperate Grasslands, Savannas and Shrublands        546.381421
#                  Tropical and Subtropical Forests                     284.278163
#                  Tropical and Subtropical Grasslands, Savannas a...   784.648127
#                  Tundra                                                 0.000000
# Isoptera         Boreal Forests/Taiga                                   0.000000
#                  Crops                                               1786.727092
#                  Deserts and Xeric Shrublands                         148.200000
#                  Mediterranean Forests, Woodlands and Scrub           902.619835
#                  Pasture                                             1044.250919
#                  Temperate Forests                                    604.553339
#                  Temperate Grasslands, Savannas and Shrublands       1404.000000
#                  Tropical and Subtropical Forests                    2278.309868
#                  Tropical and Subtropical Grasslands, Savannas a...  1499.152461
#                  Tundra                                                 0.000000
# Other            Boreal Forests/Taiga                                 333.205454
#                  Crops                                               1600.456717
#                  Pasture                                              848.713744
#                  Temperate Forests                                   1249.795663
#                  Temperate Grasslands, Savannas and Shrublands       1082.908672
#                  Tropical and Subtropical Forests                     909.579175
#                  Tropical and Subtropical Grasslands, Savannas a...   336.413591
#                  Tundra                                               100.110171
#
#                                                                        Mean_Log  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                291.142690
#                  Crops                                                65.383753
#                  Deserts and Xeric Shrublands                          2.045361
#                  Mediterranean Forests, Woodlands and Scrub            6.610139
#                  Pasture                                               2.031131
#                  Temperate Forests                                   350.418631
#                  Temperate Grasslands, Savannas and Shrublands       113.979553
#                  Tropical and Subtropical Forests                    126.006528
#                  Tropical and Subtropical Grasslands, Savannas a...   56.936426
#                  Tundra                                              114.600949
# Collembola       Boreal Forests/Taiga                                136.848532
#                  Crops                                                21.762794
#                  Deserts and Xeric Shrublands                          0.497411
#                  Mediterranean Forests, Woodlands and Scrub           28.884714
#                  Pasture                                               0.090304
#                  Temperate Forests                                   111.827618
#                  Temperate Grasslands, Savannas and Shrublands        82.978605
#                  Tropical and Subtropical Forests                     35.081698
#                  Tropical and Subtropical Grasslands, Savannas a...   12.311670
#                  Tundra                                              126.766659
# Formicidae       Boreal Forests/Taiga                                  3.702941
#                  Crops                                                25.071996
#                  Deserts and Xeric Shrublands                         24.412431
#                  Mediterranean Forests, Woodlands and Scrub           39.000000
#                  Pasture                                             102.892558
#                  Temperate Forests                                    60.625943
#                  Temperate Grasslands, Savannas and Shrublands       106.419637
#                  Tropical and Subtropical Forests                     61.147680
#                  Tropical and Subtropical Grasslands, Savannas a...  558.462082
#                  Tundra                                                0.000000
# Isoptera         Boreal Forests/Taiga                                  0.000000
#                  Crops                                               488.549306
#                  Deserts and Xeric Shrublands                          7.156020
#                  Mediterranean Forests, Woodlands and Scrub          243.271596
#                  Pasture                                              80.084077
#                  Temperate Forests                                    20.892514
#                  Temperate Grasslands, Savannas and Shrublands        31.250758
#                  Tropical and Subtropical Forests                    474.988054
#                  Tropical and Subtropical Grasslands, Savannas a...  458.918895
#                  Tundra                                                0.000000
# Other            Boreal Forests/Taiga                                 98.523566
#                  Crops                                               655.954940
#                  Pasture                                             199.967486
#                  Temperate Forests                                   681.339831
#                  Temperate Grasslands, Savannas and Shrublands       272.748943
#                  Tropical and Subtropical Forests                    146.958944
#                  Tropical and Subtropical Grasslands, Savannas a...   69.435611
#                  Tundra                                               21.849101
#
#                                                                          Mean_Ar  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                 433.063793
#                  Crops                                                 95.895059
#                  Deserts and Xeric Shrublands                           4.341672
#                  Mediterranean Forests, Woodlands and Scrub            77.754995
#                  Pasture                                               33.574536
#                  Temperate Forests                                    857.925828
#                  Temperate Grasslands, Savannas and Shrublands        285.159474
#                  Tropical and Subtropical Forests                     184.578922
#                  Tropical and Subtropical Grasslands, Savannas a...    74.122848
#                  Tundra                                               221.845380
# Collembola       Boreal Forests/Taiga                                 468.434791
#                  Crops                                                 25.011892
#                  Deserts and Xeric Shrublands                           1.195919
#                  Mediterranean Forests, Woodlands and Scrub            43.244196
#                  Pasture                                                2.963543
#                  Temperate Forests                                    292.040695
#                  Temperate Grasslands, Savannas and Shrublands        185.821648
#                  Tropical and Subtropical Forests                      46.139555
#                  Tropical and Subtropical Grasslands, Savannas a...    12.350146
#                  Tundra                                               400.188184
# Formicidae       Boreal Forests/Taiga                                   5.126447
#                  Crops                                                 64.116685
#                  Deserts and Xeric Shrublands                          58.381551
#                  Mediterranean Forests, Woodlands and Scrub            39.000000
#                  Pasture                                              135.109786
#                  Temperate Forests                                    717.040000
#                  Temperate Grasslands, Savannas and Shrublands        310.845614
#                  Tropical and Subtropical Forests                     208.057995
#                  Tropical and Subtropical Grasslands, Savannas a...   644.369553
#                  Tundra                                                 0.000000
# Isoptera         Boreal Forests/Taiga                                   0.000000
#                  Crops                                               1432.845910
#                  Deserts and Xeric Shrublands                          74.991633
#                  Mediterranean Forests, Woodlands and Scrub           579.199999
#                  Pasture                                              796.545843
#                  Temperate Forests                                    369.083333
#                  Temperate Grasslands, Savannas and Shrublands        702.300000
#                  Tropical and Subtropical Forests                    1853.567602
#                  Tropical and Subtropical Grasslands, Savannas a...  1121.690613
#                  Tundra                                                 0.000000
# Other            Boreal Forests/Taiga                                 269.509074
#                  Crops                                               1131.061111
#                  Pasture                                              668.138126
#                  Temperate Forests                                   1065.465288
#                  Temperate Grasslands, Savannas and Shrublands        809.169849
#                  Tropical and Subtropical Forests                     705.585255
#                  Tropical and Subtropical Grasslands, Savannas a...   200.294254
#                  Tundra                                                64.322099
#
#                                                                          Sem_Ar  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                 72.232197
#                  Crops                                                38.264131
#                  Deserts and Xeric Shrublands                          1.419625
#                  Mediterranean Forests, Woodlands and Scrub           43.578780
#                  Pasture                                              26.036673
#                  Temperate Forests                                   190.125672
#                  Temperate Grasslands, Savannas and Shrublands        70.722630
#                  Tropical and Subtropical Forests                     53.367340
#                  Tropical and Subtropical Grasslands, Savannas a...   47.496076
#                  Tundra                                               43.607119
# Collembola       Boreal Forests/Taiga                                264.987235
#                  Crops                                                 8.078296
#                  Deserts and Xeric Shrublands                          0.684575
#                  Mediterranean Forests, Woodlands and Scrub           12.412732
#                  Pasture                                               2.960808
#                  Temperate Forests                                    89.249435
#                  Temperate Grasslands, Savannas and Shrublands        45.622605
#                  Tropical and Subtropical Forests                     12.828114
#                  Tropical and Subtropical Grasslands, Savannas a...    0.978045
#                  Tundra                                              131.264362
# Formicidae       Boreal Forests/Taiga                                  3.585162
#                  Crops                                                21.755944
#                  Deserts and Xeric Shrublands                         31.919765
#                  Mediterranean Forests, Woodlands and Scrub                 NaN
#                  Pasture                                              29.589832
#                  Temperate Forests                                   629.053945
#                  Temperate Grasslands, Savannas and Shrublands       235.535807
#                  Tropical and Subtropical Forests                     76.220168
#                  Tropical and Subtropical Grasslands, Savannas a...  140.278574
#                  Tundra                                                0.000000
# Isoptera         Boreal Forests/Taiga                                       NaN
#                  Crops                                               353.881182
#                  Deserts and Xeric Shrublands                         73.208368
#                  Mediterranean Forests, Woodlands and Scrub          323.419835
#                  Pasture                                             247.705076
#                  Temperate Forests                                   235.470006
#                  Temperate Grasslands, Savannas and Shrublands       701.700000
#                  Tropical and Subtropical Forests                    424.742265
#                  Tropical and Subtropical Grasslands, Savannas a...  377.461848
#                  Tundra                                                0.000000
# Other            Boreal Forests/Taiga                                 63.696381
#                  Crops                                               469.395606
#                  Pasture                                             180.575618
#                  Temperate Forests                                   184.330375
#                  Temperate Grasslands, Savannas and Shrublands       273.738823
#                  Tropical and Subtropical Forests                    203.993920
#                  Tropical and Subtropical Grasslands, Savannas a...  136.119338
#                  Tundra                                               35.788071
#
#                                                                       N
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                22
#                  Crops                                                7
#                  Deserts and Xeric Shrublands                         7
#                  Mediterranean Forests, Woodlands and Scrub          12
#                  Pasture                                             11
#                  Temperate Forests                                   51
#                  Temperate Grasslands, Savannas and Shrublands       18
#                  Tropical and Subtropical Forests                     9
#                  Tropical and Subtropical Grasslands, Savannas a...   2
#                  Tundra                                              51
# Collembola       Boreal Forests/Taiga                                21
#                  Crops                                                4
#                  Deserts and Xeric Shrublands                         6
#                  Mediterranean Forests, Woodlands and Scrub           8
#                  Pasture                                              9
#                  Temperate Forests                                   48
#                  Temperate Grasslands, Savannas and Shrublands       19
#                  Tropical and Subtropical Forests                    13
#                  Tropical and Subtropical Grasslands, Savannas a...   2
#                  Tundra                                              40
# Formicidae       Boreal Forests/Taiga                                 2
#                  Crops                                                8
#                  Deserts and Xeric Shrublands                         5
#                  Mediterranean Forests, Woodlands and Scrub           1
#                  Pasture                                             11
#                  Temperate Forests                                   25
#                  Temperate Grasslands, Savannas and Shrublands        7
#                  Tropical and Subtropical Forests                    25
#                  Tropical and Subtropical Grasslands, Savannas a...   7
#                  Tundra                                               2
# Isoptera         Boreal Forests/Taiga                                 1
#                  Crops                                               26
#                  Deserts and Xeric Shrublands                         3
#                  Mediterranean Forests, Woodlands and Scrub           4
#                  Pasture                                             29
#                  Temperate Forests                                    6
#                  Temperate Grasslands, Savannas and Shrublands        2
#                  Tropical and Subtropical Forests                    64
#                  Tropical and Subtropical Grasslands, Savannas a...  23
#                  Tundra                                               2
# Other            Boreal Forests/Taiga                                16
#                  Crops                                                9
#                  Pasture                                             13
#                  Temperate Forests                                   31
#                  Temperate Grasslands, Savannas and Shrublands       13
#                  Tropical and Subtropical Forests                    22
#                  Tropical and Subtropical Grasslands, Savannas a...   5
#                  Tundra                                              14

# %%
#Functions that help to handel the bootstrapped data and help in the Monte Carlo process for the total sum

#~~~ Think how to improve this function to reduce the effects of bin position and number of bins. Perhaps using a kde?

def means_to_cdf(means, Nbins=20): #converts the means array into a descrete cdf (cumulative distribution function) using a histogram with Nbins bins. 
    hist, bin_edges = np.histogram(means, bins = Nbins, density = False)
    bin_centers = (bin_edges[:-1] + bin_edges[1:] )/2
    cdf = np.cumsum(hist)
    cdf = cdf / cdf[-1]
    return cdf, bin_centers

def random_from_cdf(cdf,bin_centers,N): #picks N values of bin_centers according to the histogram's cdf
    values = np.random.rand(N)
    value_bins_indx = np.searchsorted(cdf, values)
    rnd_from_cdf = bin_centers[value_bins_indx]
    return rnd_from_cdf

# %%
#extract the data for bootstrapping, and make the calculation using a for loop
x = soil_site_data_mass_all.set_index(['aggregated taxon','aggregated biome'])['mass_G'].sort_index()
sigma = soil_site_data_mass_all_std.set_index(['aggregated taxon','aggregated biome'])['mass_G'].sort_index()

soil_biome_mean_std_boot = pd.DataFrame(index = x.index.unique(), columns=['mean','2.5%','97.5%']) #initialize the bootstrap array for soil data
soil_means_dist = pd.DataFrame(index = x.index.unique(), columns=['cdf','values']) #initialize the means distribution array 

#Parameters for bootstrapping: (change to control precision and runtime)
NBins = 20
Boot_N = 1000

for taxon, biome in x.index.unique():
    means = Boot_means(x.loc[taxon,biome], sigma.loc[taxon,biome],Boot_N = Boot_N)
    soil_biome_mean_std_boot.loc[taxon,biome] = Boot_stats(means, prcnt_low=2.5, prcnt_high=97.5)
    soil_means_dist.loc[taxon,biome] = means_to_cdf(means, Nbins=NBins)
    
soil_biome_mean_std_boot
# Out:
#                                                                         mean  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                430.583
#                  Crops                                               93.5406
#                  Deserts and Xeric Shrublands                        4.36367
#                  Mediterranean Forests, Woodlands and Scrub          75.5885
#                  Pasture                                             33.3265
#                  Temperate Forests                                   856.809
#                  Temperate Grasslands, Savannas and Shrublands       283.594
#                  Tropical and Subtropical Forests                    184.767
#                  Tropical and Subtropical Grasslands, Savannas a...  73.4579
#                  Tundra                                              222.098
# Collembola       Boreal Forests/Taiga                                470.535
#                  Crops                                               24.9836
#                  Deserts and Xeric Shrublands                        1.16626
#                  Mediterranean Forests, Woodlands and Scrub          42.9347
#                  Pasture                                             2.96063
#                  Temperate Forests                                   294.186
#                  Temperate Grasslands, Savannas and Shrublands       188.323
#                  Tropical and Subtropical Forests                    46.3037
#                  Tropical and Subtropical Grasslands, Savannas a...  12.3541
#                  Tundra                                              401.838
# Formicidae       Boreal Forests/Taiga                                5.13362
#                  Crops                                                63.662
#                  Deserts and Xeric Shrublands                        58.4618
#                  Mediterranean Forests, Woodlands and Scrub               39
#                  Pasture                                             136.667
#                  Temperate Forests                                   781.034
#                  Temperate Grasslands, Savannas and Shrublands       319.005
#                  Tropical and Subtropical Forests                    245.312
#                  Tropical and Subtropical Grasslands, Savannas a...   644.05
#                  Tundra                                                    0
# Isoptera         Boreal Forests/Taiga                                      0
#                  Crops                                               1459.69
#                  Deserts and Xeric Shrublands                        73.0793
#                  Mediterranean Forests, Woodlands and Scrub          570.559
#                  Pasture                                              784.36
#                  Temperate Forests                                   369.152
#                  Temperate Grasslands, Savannas and Shrublands       697.358
#                  Tropical and Subtropical Forests                    1847.03
#                  Tropical and Subtropical Grasslands, Savannas a...  1113.35
#                  Tundra                                                    0
# Other            Boreal Forests/Taiga                                269.683
#                  Crops                                               1121.66
#                  Pasture                                             680.244
#                  Temperate Forests                                   1073.74
#                  Temperate Grasslands, Savannas and Shrublands       823.399
#                  Tropical and Subtropical Forests                    703.415
#                  Tropical and Subtropical Grasslands, Savannas a...  198.878
#                  Tundra                                              64.6546
#
#                                                                          2.5%  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                 291.647
#                  Crops                                                42.0551
#                  Deserts and Xeric Shrublands                         1.71987
#                  Mediterranean Forests, Woodlands and Scrub           18.6904
#                  Pasture                                              1.83456
#                  Temperate Forests                                    537.913
#                  Temperate Grasslands, Savannas and Shrublands        165.491
#                  Tropical and Subtropical Forests                     95.8864
#                  Tropical and Subtropical Grasslands, Savannas a...   26.6268
#                  Tundra                                               144.397
# Collembola       Boreal Forests/Taiga                                 107.223
#                  Crops                                                14.5679
#                  Deserts and Xeric Shrublands                        0.214451
#                  Mediterranean Forests, Woodlands and Scrub           22.7008
#                  Pasture                                                    0
#                  Temperate Forests                                    160.185
#                  Temperate Grasslands, Savannas and Shrublands        111.697
#                  Tropical and Subtropical Forests                     27.5646
#                  Tropical and Subtropical Grasslands, Savannas a...   11.3721
#                  Tundra                                               195.816
# Formicidae       Boreal Forests/Taiga                                 1.54128
#                  Crops                                                25.5119
#                  Deserts and Xeric Shrublands                         10.1631
#                  Mediterranean Forests, Woodlands and Scrub                39
#                  Pasture                                              77.8211
#                  Temperate Forests                                    49.8151
#                  Temperate Grasslands, Savannas and Shrublands        54.8428
#                  Tropical and Subtropical Forests                     66.9605
#                  Tropical and Subtropical Grasslands, Savannas a...   415.245
#                  Tundra                                                     0
# Isoptera         Boreal Forests/Taiga                                       0
#                  Crops                                                800.128
#                  Deserts and Xeric Shrublands                        0.431819
#                  Mediterranean Forests, Woodlands and Scrub           60.7051
#                  Pasture                                              367.648
#                  Temperate Forests                                     5.8235
#                  Temperate Grasslands, Savannas and Shrublands            0.6
#                  Tropical and Subtropical Forests                     1167.64
#                  Tropical and Subtropical Grasslands, Savannas a...   577.026
#                  Tundra                                                     0
# Other            Boreal Forests/Taiga                                 146.341
#                  Crops                                                409.623
#                  Pasture                                              302.389
#                  Temperate Forests                                    740.233
#                  Temperate Grasslands, Savannas and Shrublands        334.475
#                  Tropical and Subtropical Forests                      300.84
#                  Tropical and Subtropical Grasslands, Savannas a...     24.94
#                  Tundra                                               20.3463
#
#                                                                        97.5%
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                577.333
#                  Crops                                               174.458
#                  Deserts and Xeric Shrublands                        6.85315
#                  Mediterranean Forests, Woodlands and Scrub          168.521
#                  Pasture                                             86.8738
#                  Temperate Forests                                    1258.6
#                  Temperate Grasslands, Savannas and Shrublands       425.103
#                  Tropical and Subtropical Forests                     282.79
#                  Tropical and Subtropical Grasslands, Savannas a...  121.619
#                  Tundra                                              313.792
# Collembola       Boreal Forests/Taiga                                1050.13
#                  Crops                                               40.5757
#                  Deserts and Xeric Shrublands                        2.60602
#                  Mediterranean Forests, Woodlands and Scrub          68.1085
#                  Pasture                                              8.8862
#                  Temperate Forests                                   490.074
#                  Temperate Grasslands, Savannas and Shrublands       292.952
#                  Tropical and Subtropical Forests                    74.6635
#                  Tropical and Subtropical Grasslands, Savannas a...  13.3282
#                  Tundra                                              693.328
# Formicidae       Boreal Forests/Taiga                                8.71161
#                  Crops                                               115.023
#                  Deserts and Xeric Shrublands                        120.782
#                  Mediterranean Forests, Woodlands and Scrub               39
#                  Pasture                                             206.047
#                  Temperate Forests                                    3062.1
#                  Temperate Grasslands, Savannas and Shrublands       791.041
#                  Tropical and Subtropical Forests                    598.639
#                  Tropical and Subtropical Grasslands, Savannas a...  935.339
#                  Tundra                                                    0
# Isoptera         Boreal Forests/Taiga                                      0
#                  Crops                                               2301.79
#                  Deserts and Xeric Shrublands                          221.4
#                  Mediterranean Forests, Woodlands and Scrub          1105.26
#                  Pasture                                             1359.44
#                  Temperate Forests                                   812.704
#                  Temperate Grasslands, Savannas and Shrublands       1840.18
#                  Tropical and Subtropical Forests                    2685.26
#                  Tropical and Subtropical Grasslands, Savannas a...  1985.97
#                  Tundra                                                    0
# Other            Boreal Forests/Taiga                                391.629
#                  Crops                                               2230.09
#                  Pasture                                             1073.36
#                  Temperate Forests                                   1466.66
#                  Temperate Grasslands, Savannas and Shrublands       1397.69
#                  Tropical and Subtropical Forests                    1157.98
#                  Tropical and Subtropical Grasslands, Savannas a...  461.161
#                  Tundra                                              143.199

# %%
#example (~~~can be modified and removed)
x = soil_site_data_mass_all.set_index(['aggregated taxon','aggregated biome'])['mass_G'].sort_index()
sigma = soil_site_data_mass_all_std.set_index(['aggregated taxon','aggregated biome'])['mass_G'].sort_index()

NBins = 20
Boot_N = 10000

taxon = 'Isoptera'
biome = 'Temperate Forests'

means = Boot_means(x.loc[taxon,biome], sigma.loc[taxon,biome],Boot_N = Boot_N)
plt.hist(means,50)
# Out:
# (array([8.070e+02, 1.100e+02, 0.000e+00, 0.000e+00, 0.000e+00, 9.410e+02,
#         3.280e+02, 2.000e+00, 1.130e+02, 1.131e+03, 4.610e+02, 4.410e+02,
#         6.000e+00, 0.000e+00, 1.446e+03, 1.990e+02, 2.690e+02, 2.750e+02,
#         5.370e+02, 5.440e+02, 2.730e+02, 5.400e+01, 1.000e+00, 7.620e+02,
#         4.500e+01, 1.880e+02, 1.610e+02, 1.340e+02, 2.740e+02, 5.300e+01,
#         2.400e+01, 0.000e+00, 2.240e+02, 3.400e+01, 1.600e+01, 4.300e+01,
#         6.000e+00, 5.300e+01, 0.000e+00, 2.000e+00, 0.000e+00, 2.600e+01,
#         6.000e+00, 0.000e+00, 6.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 3.000e+00]),
#  array([8.15844855e-02, 2.52799528e+01, 5.04783211e+01, 7.56766894e+01,
#         1.00875058e+02, 1.26073426e+02, 1.51271794e+02, 1.76470163e+02,
#         2.01668531e+02, 2.26866899e+02, 2.52065268e+02, 2.77263636e+02,
#         3.02462004e+02, 3.27660373e+02, 3.52858741e+02, 3.78057109e+02,
#         4.03255477e+02, 4.28453846e+02, 4.53652214e+02, 4.78850582e+02,
#         5.04048951e+02, 5.29247319e+02, 5.54445687e+02, 5.79644056e+02,
#         6.04842424e+02, 6.30040792e+02, 6.55239161e+02, 6.80437529e+02,
#         7.05635897e+02, 7.30834265e+02, 7.56032634e+02, 7.81231002e+02,
#         8.06429370e+02, 8.31627739e+02, 8.56826107e+02, 8.82024475e+02,
#         9.07222844e+02, 9.32421212e+02, 9.57619580e+02, 9.82817949e+02,
#         1.00801632e+03, 1.03321469e+03, 1.05841305e+03, 1.08361142e+03,
#         1.10880979e+03, 1.13400816e+03, 1.15920653e+03, 1.18440490e+03,
#         1.20960326e+03, 1.23480163e+03, 1.26000000e+03]),
#  <a list of 50 Patch objects>)

# %%
##with alternative mean (~~~ remove all alternative means in the future?)
soil_biome_means_2 = soil_site_data_mass_all.reset_index().groupby(['aggregated taxon','aggregated biome'])['mass_G'].agg([calc_mean,calc_mean_ar,calc_mean_log,calc_mean_alt,calc_min,calc_max,calc_min_alt,calc_max_alt,calc_mean_ar_sem,'count'])
soil_biome_means_2.rename(columns={'calc_mean': 'Mean', 'calc_min': 'Min', 'calc_max': 'Max', 'calc_mean_log': 'Mean_Log', 'calc_mean_ar': 'Mean_Ar','calc_mean_ar_sem': 'Sem_Ar', 'count': 'N','count': 'N', 'calc_mean_alt':'Mean_alt','calc_min_alt': 'Min_alt', 'calc_max_alt': 'Max_alt'}, inplace=True)

#compare the means
soil_biome_means_2.div(soil_biome_means_2.Mean_Ar, axis=0) # soil_biome_means_2.loc[:,'Mean']
# Out:
#                                                                          Mean  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                0.836143
#                  Crops                                               0.840913
#                  Deserts and Xeric Shrublands                        0.735550
#                  Mediterranean Forests, Woodlands and Scrub          0.542506
#                  Pasture                                             0.530248
#                  Temperate Forests                                   0.704224
#                  Temperate Grasslands, Savannas and Shrublands       0.699852
#                  Tropical and Subtropical Forests                    0.841335
#                  Tropical and Subtropical Grasslands, Savannas a...  0.884068
#                  Tundra                                              0.758290
# Collembola       Boreal Forests/Taiga                                0.646070
#                  Crops                                               0.935049
#                  Deserts and Xeric Shrublands                        0.707962
#                  Mediterranean Forests, Woodlands and Scrub          0.833972
#                  Pasture                                             0.515236
#                  Temperate Forests                                   0.691459
#                  Temperate Grasslands, Savannas and Shrublands       0.723275
#                  Tropical and Subtropical Forests                    0.880169
#                  Tropical and Subtropical Grasslands, Savannas a...  0.998442
#                  Tundra                                              0.658384
# Formicidae       Boreal Forests/Taiga                                0.861161
#                  Crops                                               0.695518
#                  Deserts and Xeric Shrublands                        0.709077
#                  Mediterranean Forests, Woodlands and Scrub          1.000000
#                  Pasture                                             0.880774
#                  Temperate Forests                                   0.542275
#                  Temperate Grasslands, Savannas and Shrublands       0.671178
#                  Tropical and Subtropical Forests                    0.646949
#                  Tropical and Subtropical Grasslands, Savannas a...  0.933340
#                  Tundra                                                   NaN
# Isoptera         Boreal Forests/Taiga                                     NaN
#                  Crops                                               0.670482
#                  Deserts and Xeric Shrublands                        0.547712
#                  Mediterranean Forests, Woodlands and Scrub          0.710007
#                  Pasture                                             0.550270
#                  Temperate Forests                                   0.528303
#                  Temperate Grasslands, Savannas and Shrublands       0.522249
#                  Tropical and Subtropical Forests                    0.628128
#                  Tropical and Subtropical Grasslands, Savannas a...  0.704566
#                  Tundra                                                   NaN
# Other            Boreal Forests/Taiga                                0.682783
#                  Crops                                               0.789973
#                  Pasture                                             0.649645
#                  Temperate Forests                                   0.819738
#                  Temperate Grasslands, Savannas and Shrublands       0.668536
#                  Tropical and Subtropical Forests                    0.604140
#                  Tropical and Subtropical Grasslands, Savannas a...  0.673334
#                  Tundra                                              0.669841
#
#                                                                      Mean_Ar  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                    1.0
#                  Crops                                                   1.0
#                  Deserts and Xeric Shrublands                            1.0
#                  Mediterranean Forests, Woodlands and Scrub              1.0
#                  Pasture                                                 1.0
#                  Temperate Forests                                       1.0
#                  Temperate Grasslands, Savannas and Shrublands           1.0
#                  Tropical and Subtropical Forests                        1.0
#                  Tropical and Subtropical Grasslands, Savannas a...      1.0
#                  Tundra                                                  1.0
# Collembola       Boreal Forests/Taiga                                    1.0
#                  Crops                                                   1.0
#                  Deserts and Xeric Shrublands                            1.0
#                  Mediterranean Forests, Woodlands and Scrub              1.0
#                  Pasture                                                 1.0
#                  Temperate Forests                                       1.0
#                  Temperate Grasslands, Savannas and Shrublands           1.0
#                  Tropical and Subtropical Forests                        1.0
#                  Tropical and Subtropical Grasslands, Savannas a...      1.0
#                  Tundra                                                  1.0
# Formicidae       Boreal Forests/Taiga                                    1.0
#                  Crops                                                   1.0
#                  Deserts and Xeric Shrublands                            1.0
#                  Mediterranean Forests, Woodlands and Scrub              1.0
#                  Pasture                                                 1.0
#                  Temperate Forests                                       1.0
#                  Temperate Grasslands, Savannas and Shrublands           1.0
#                  Tropical and Subtropical Forests                        1.0
#                  Tropical and Subtropical Grasslands, Savannas a...      1.0
#                  Tundra                                                  NaN
# Isoptera         Boreal Forests/Taiga                                    NaN
#                  Crops                                                   1.0
#                  Deserts and Xeric Shrublands                            1.0
#                  Mediterranean Forests, Woodlands and Scrub              1.0
#                  Pasture                                                 1.0
#                  Temperate Forests                                       1.0
#                  Temperate Grasslands, Savannas and Shrublands           1.0
#                  Tropical and Subtropical Forests                        1.0
#                  Tropical and Subtropical Grasslands, Savannas a...      1.0
#                  Tundra                                                  NaN
# Other            Boreal Forests/Taiga                                    1.0
#                  Crops                                                   1.0
#                  Pasture                                                 1.0
#                  Temperate Forests                                       1.0
#                  Temperate Grasslands, Savannas and Shrublands           1.0
#                  Tropical and Subtropical Forests                        1.0
#                  Tropical and Subtropical Grasslands, Savannas a...      1.0
#                  Tundra                                                  1.0
#
#                                                                      Mean_Log  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                0.672286
#                  Crops                                               0.681826
#                  Deserts and Xeric Shrublands                        0.471100
#                  Mediterranean Forests, Woodlands and Scrub          0.085012
#                  Pasture                                             0.060496
#                  Temperate Forests                                   0.408449
#                  Temperate Grasslands, Savannas and Shrublands       0.399705
#                  Tropical and Subtropical Forests                    0.682670
#                  Tropical and Subtropical Grasslands, Savannas a...  0.768136
#                  Tundra                                              0.516580
# Collembola       Boreal Forests/Taiga                                0.292140
#                  Crops                                               0.870098
#                  Deserts and Xeric Shrublands                        0.415923
#                  Mediterranean Forests, Woodlands and Scrub          0.667944
#                  Pasture                                             0.030472
#                  Temperate Forests                                   0.382918
#                  Temperate Grasslands, Savannas and Shrublands       0.446550
#                  Tropical and Subtropical Forests                    0.760339
#                  Tropical and Subtropical Grasslands, Savannas a...  0.996885
#                  Tundra                                              0.316768
# Formicidae       Boreal Forests/Taiga                                0.722321
#                  Crops                                               0.391037
#                  Deserts and Xeric Shrublands                        0.418153
#                  Mediterranean Forests, Woodlands and Scrub          1.000000
#                  Pasture                                             0.761548
#                  Temperate Forests                                   0.084550
#                  Temperate Grasslands, Savannas and Shrublands       0.342355
#                  Tropical and Subtropical Forests                    0.293897
#                  Tropical and Subtropical Grasslands, Savannas a...  0.866680
#                  Tundra                                                   NaN
# Isoptera         Boreal Forests/Taiga                                     NaN
#                  Crops                                               0.340964
#                  Deserts and Xeric Shrublands                        0.095424
#                  Mediterranean Forests, Woodlands and Scrub          0.420013
#                  Pasture                                             0.100539
#                  Temperate Forests                                   0.056606
#                  Temperate Grasslands, Savannas and Shrublands       0.044498
#                  Tropical and Subtropical Forests                    0.256256
#                  Tropical and Subtropical Grasslands, Savannas a...  0.409131
#                  Tundra                                                   NaN
# Other            Boreal Forests/Taiga                                0.365567
#                  Crops                                               0.579947
#                  Pasture                                             0.299291
#                  Temperate Forests                                   0.639476
#                  Temperate Grasslands, Savannas and Shrublands       0.337073
#                  Tropical and Subtropical Forests                    0.208279
#                  Tropical and Subtropical Grasslands, Savannas a...  0.346668
#                  Tundra                                              0.339683
#
#                                                                        Mean_alt  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                  1.060711
#                  Crops                                                 0.920497
#                  Deserts and Xeric Shrublands                          1.431682
#                  Mediterranean Forests, Woodlands and Scrub           30.253786
#                  Pasture                                               2.901698
#                  Temperate Forests                                     1.117752
#                  Temperate Grasslands, Savannas and Shrublands         1.940246
#                  Tropical and Subtropical Forests                      0.994946
#                  Tropical and Subtropical Grasslands, Savannas a...    1.000000
#                  Tundra                                                0.975295
# Collembola       Boreal Forests/Taiga                                  0.587697
#                  Crops                                                 0.959742
#                  Deserts and Xeric Shrublands                          0.999950
#                  Mediterranean Forests, Woodlands and Scrub            1.040268
#                  Pasture                                               0.223434
#                  Temperate Forests                                     1.097629
#                  Temperate Grasslands, Savannas and Shrublands         2.292045
#                  Tropical and Subtropical Forests                      0.934107
#                  Tropical and Subtropical Grasslands, Savannas a...    1.000000
#                  Tundra                                                0.912522
# Formicidae       Boreal Forests/Taiga                                  1.000000
#                  Crops                                                 6.143848
#                  Deserts and Xeric Shrublands                          1.196390
#                  Mediterranean Forests, Woodlands and Scrub            1.000000
#                  Pasture                                               1.003381
#                  Temperate Forests                                     0.251710
#                  Temperate Grasslands, Savannas and Shrublands         0.642172
#                  Tropical and Subtropical Forests                      0.915457
#                  Tropical and Subtropical Grasslands, Savannas a...    0.981583
#                  Tundra                                                     NaN
# Isoptera         Boreal Forests/Taiga                                       NaN
#                  Crops                                                 2.929583
#                  Deserts and Xeric Shrublands                         46.156420
#                  Mediterranean Forests, Woodlands and Scrub            1.627000
#                  Pasture                                              14.868848
#                  Temperate Forests                                   362.835708
#                  Temperate Grasslands, Savannas and Shrublands         1.000000
#                  Tropical and Subtropical Forests                      2.871373
#                  Tropical and Subtropical Grasslands, Savannas a...    2.585846
#                  Tundra                                                     NaN
# Other            Boreal Forests/Taiga                                  3.381450
#                  Crops                                                 0.904340
#                  Pasture                                               3.800617
#                  Temperate Forests                                     1.087166
#                  Temperate Grasslands, Savannas and Shrublands         3.042321
#                  Tropical and Subtropical Forests                      2.297444
#                  Tropical and Subtropical Grasslands, Savannas a...    1.130662
#                  Tundra                                                0.899082
#
#                                                                           Min  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                0.672286
#                  Crops                                               0.600979
#                  Deserts and Xeric Shrublands                        0.471100
#                  Mediterranean Forests, Woodlands and Scrub          0.085012
#                  Pasture                                             0.060496
#                  Temperate Forests                                   0.408449
#                  Temperate Grasslands, Savannas and Shrublands       0.399705
#                  Tropical and Subtropical Forests                    0.682670
#                  Tropical and Subtropical Grasslands, Savannas a...  0.359225
#                  Tundra                                              0.516580
# Collembola       Boreal Forests/Taiga                                0.292140
#                  Crops                                               0.677022
#                  Deserts and Xeric Shrublands                        0.415923
#                  Mediterranean Forests, Woodlands and Scrub          0.667944
#                  Pasture                                             0.000923
#                  Temperate Forests                                   0.382918
#                  Temperate Grasslands, Savannas and Shrublands       0.446550
#                  Tropical and Subtropical Forests                    0.721971
#                  Tropical and Subtropical Grasslands, Savannas a...  0.920807
#                  Tundra                                              0.316768
# Formicidae       Boreal Forests/Taiga                                0.300654
#                  Crops                                               0.391037
#                  Deserts and Xeric Shrublands                        0.418153
#                  Mediterranean Forests, Woodlands and Scrub          1.000000
#                  Pasture                                             0.761548
#                  Temperate Forests                                   0.084550
#                  Temperate Grasslands, Savannas and Shrublands       0.242274
#                  Tropical and Subtropical Forests                    0.293897
#                  Tropical and Subtropical Grasslands, Savannas a...  0.782301
#                  Tundra                                                   NaN
# Isoptera         Boreal Forests/Taiga                                     NaN
#                  Crops                                               0.340964
#                  Deserts and Xeric Shrublands                        0.023780
#                  Mediterranean Forests, Woodlands and Scrub          0.420013
#                  Pasture                                             0.100539
#                  Temperate Forests                                   0.056606
#                  Temperate Grasslands, Savannas and Shrublands       0.000854
#                  Tropical and Subtropical Forests                    0.256256
#                  Tropical and Subtropical Grasslands, Savannas a...  0.409131
#                  Tundra                                                   NaN
# Other            Boreal Forests/Taiga                                0.365567
#                  Crops                                               0.579947
#                  Pasture                                             0.299291
#                  Temperate Forests                                   0.639476
#                  Temperate Grasslands, Savannas and Shrublands       0.337073
#                  Tropical and Subtropical Forests                    0.208279
#                  Tropical and Subtropical Grasslands, Savannas a...  0.320403
#                  Tundra                                              0.339683
#
#                                                                           Max  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                1.166793
#                  Crops                                               1.399021
#                  Deserts and Xeric Shrublands                        1.326977
#                  Mediterranean Forests, Woodlands and Scrub          1.560463
#                  Pasture                                             1.775489
#                  Temperate Forests                                   1.221611
#                  Temperate Grasslands, Savannas and Shrublands       1.248011
#                  Tropical and Subtropical Forests                    1.289130
#                  Tropical and Subtropical Grasslands, Savannas a...  1.640775
#                  Tundra                                              1.196565
# Collembola       Boreal Forests/Taiga                                1.565686
#                  Crops                                               1.322978
#                  Deserts and Xeric Shrublands                        1.572426
#                  Mediterranean Forests, Woodlands and Scrub          1.287038
#                  Pasture                                             1.999077
#                  Temperate Forests                                   1.305606
#                  Temperate Grasslands, Savannas and Shrublands       1.245518
#                  Tropical and Subtropical Forests                    1.278029
#                  Tropical and Subtropical Grasslands, Savannas a...  1.079193
#                  Tundra                                              1.328007
# Formicidae       Boreal Forests/Taiga                                1.699346
#                  Crops                                               1.339318
#                  Deserts and Xeric Shrublands                        1.546744
#                  Mediterranean Forests, Woodlands and Scrub          1.000000
#                  Pasture                                             1.219006
#                  Temperate Forests                                   1.877293
#                  Temperate Grasslands, Savannas and Shrublands       1.757726
#                  Tropical and Subtropical Forests                    1.366341
#                  Tropical and Subtropical Grasslands, Savannas a...  1.217699
#                  Tundra                                                   NaN
# Isoptera         Boreal Forests/Taiga                                     NaN
#                  Crops                                               1.246978
#                  Deserts and Xeric Shrublands                        1.976220
#                  Mediterranean Forests, Woodlands and Scrub          1.558391
#                  Pasture                                             1.310974
#                  Temperate Forests                                   1.637986
#                  Temperate Grasslands, Savannas and Shrublands       1.999146
#                  Tropical and Subtropical Forests                    1.229149
#                  Tropical and Subtropical Grasslands, Savannas a...  1.336512
#                  Tundra                                                   NaN
# Other            Boreal Forests/Taiga                                1.236342
#                  Crops                                               1.415005
#                  Pasture                                             1.270267
#                  Temperate Forests                                   1.173005
#                  Temperate Grasslands, Savannas and Shrublands       1.338296
#                  Tropical and Subtropical Forests                    1.289113
#                  Tropical and Subtropical Grasslands, Savannas a...  1.679597
#                  Tundra                                              1.556388
#
#                                                                       Min_alt  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                0.659016
#                  Crops                                               0.462034
#                  Deserts and Xeric Shrublands                        0.253679
#                  Mediterranean Forests, Woodlands and Scrub          0.126596
#                  Pasture                                             0.062872
#                  Temperate Forests                                   0.657030
#                  Temperate Grasslands, Savannas and Shrublands       0.534846
#                  Tropical and Subtropical Forests                    0.501182
#                  Tropical and Subtropical Grasslands, Savannas a...  0.359225
#                  Tundra                                              0.663175
# Collembola       Boreal Forests/Taiga                                0.307502
#                  Crops                                               0.574613
#                  Deserts and Xeric Shrublands                        0.177179
#                  Mediterranean Forests, Woodlands and Scrub          0.459577
#                  Pasture                                             0.011269
#                  Temperate Forests                                   0.623339
#                  Temperate Grasslands, Savannas and Shrublands       0.634196
#                  Tropical and Subtropical Forests                    0.633637
#                  Tropical and Subtropical Grasslands, Savannas a...  0.920807
#                  Tundra                                              0.489752
# Formicidae       Boreal Forests/Taiga                                0.300654
#                  Crops                                               0.227439
#                  Deserts and Xeric Shrublands                        0.167317
#                  Mediterranean Forests, Woodlands and Scrub          1.000000
#                  Pasture                                             0.605662
#                  Temperate Forests                                   0.111887
#                  Temperate Grasslands, Savannas and Shrublands       0.209218
#                  Tropical and Subtropical Forests                    0.397025
#                  Tropical and Subtropical Grasslands, Savannas a...  0.649903
#                  Tundra                                                   NaN
# Isoptera         Boreal Forests/Taiga                                     NaN
#                  Crops                                               0.761804
#                  Deserts and Xeric Shrublands                        0.001086
#                  Mediterranean Forests, Woodlands and Scrub          0.118548
#                  Pasture                                             0.857602
#                  Temperate Forests                                   0.009060
#                  Temperate Grasslands, Savannas and Shrublands       0.000854
#                  Tropical and Subtropical Forests                    1.141965
#                  Tropical and Subtropical Grasslands, Savannas a...  0.725577
#                  Tundra                                                   NaN
# Other            Boreal Forests/Taiga                                0.532891
#                  Crops                                               0.421809
#                  Pasture                                             0.358068
#                  Temperate Forests                                   0.700177
#                  Temperate Grasslands, Savannas and Shrublands       0.382796
#                  Tropical and Subtropical Forests                    0.449321
#                  Tropical and Subtropical Grasslands, Savannas a...  0.133630
#                  Tundra                                              0.323016
#
#                                                                           Max_alt  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                    1.815302
#                  Crops                                                   2.060027
#                  Deserts and Xeric Shrublands                            9.918390
#                  Mediterranean Forests, Woodlands and Scrub            601.207176
#                  Pasture                                                47.785846
#                  Temperate Forests                                       2.057435
#                  Temperate Grasslands, Savannas and Shrublands           9.956825
#                  Tropical and Subtropical Forests                        2.222039
#                  Tropical and Subtropical Grasslands, Savannas a...      1.640775
#                  Tundra                                                  1.494194
# Collembola       Boreal Forests/Taiga                                    1.256529
#                  Crops                                                   1.711732
#                  Deserts and Xeric Shrublands                            5.768478
#                  Mediterranean Forests, Woodlands and Scrub              2.750574
#                  Pasture                                                 1.920916
#                  Temperate Forests                                       2.113260
#                  Temperate Grasslands, Savannas and Shrublands          11.758285
#                  Tropical and Subtropical Forests                        1.433254
#                  Tropical and Subtropical Grasslands, Savannas a...      1.079193
#                  Tundra                                                  1.893032
# Formicidae       Boreal Forests/Taiga                                    1.699346
#                  Crops                                                  87.025578
#                  Deserts and Xeric Shrublands                            9.683471
#                  Mediterranean Forests, Woodlands and Scrub              1.000000
#                  Pasture                                                 1.777745
#                  Temperate Forests                                       0.674141
#                  Temperate Grasslands, Savannas and Shrublands           2.499523
#                  Tropical and Subtropical Forests                        2.538450
#                  Tropical and Subtropical Grasslands, Savannas a...      1.550921
#                  Tundra                                                       NaN
# Isoptera         Boreal Forests/Taiga                                         NaN
#                  Crops                                                  16.806910
#                  Deserts and Xeric Shrublands                         2301.583054
#                  Mediterranean Forests, Woodlands and Scrub             17.218311
#                  Pasture                                               263.962926
#                  Temperate Forests                                   19328.851741
#                  Temperate Grasslands, Savannas and Shrublands           1.999146
#                  Tropical and Subtropical Forests                        9.220675
#                  Tropical and Subtropical Grasslands, Savannas a...     13.240012
#                  Tundra                                                       NaN
# Other            Boreal Forests/Taiga                                   30.981654
#                  Crops                                                   2.235173
#                  Pasture                                                45.838025
#                  Temperate Forests                                       1.779865
#                  Temperate Grasslands, Savannas and Shrublands          31.405291
#                  Tropical and Subtropical Forests                       18.192979
#                  Tropical and Subtropical Grasslands, Savannas a...     10.086852
#                  Tundra                                                  3.180824
#
#                                                                        Sem_Ar  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                0.166793
#                  Crops                                               0.399021
#                  Deserts and Xeric Shrublands                        0.326977
#                  Mediterranean Forests, Woodlands and Scrub          0.560463
#                  Pasture                                             0.775489
#                  Temperate Forests                                   0.221611
#                  Temperate Grasslands, Savannas and Shrublands       0.248011
#                  Tropical and Subtropical Forests                    0.289130
#                  Tropical and Subtropical Grasslands, Savannas a...  0.640775
#                  Tundra                                              0.196565
# Collembola       Boreal Forests/Taiga                                0.565686
#                  Crops                                               0.322978
#                  Deserts and Xeric Shrublands                        0.572426
#                  Mediterranean Forests, Woodlands and Scrub          0.287038
#                  Pasture                                             0.999077
#                  Temperate Forests                                   0.305606
#                  Temperate Grasslands, Savannas and Shrublands       0.245518
#                  Tropical and Subtropical Forests                    0.278029
#                  Tropical and Subtropical Grasslands, Savannas a...  0.079193
#                  Tundra                                              0.328007
# Formicidae       Boreal Forests/Taiga                                0.699346
#                  Crops                                               0.339318
#                  Deserts and Xeric Shrublands                        0.546744
#                  Mediterranean Forests, Woodlands and Scrub               NaN
#                  Pasture                                             0.219006
#                  Temperate Forests                                   0.877293
#                  Temperate Grasslands, Savannas and Shrublands       0.757726
#                  Tropical and Subtropical Forests                    0.366341
#                  Tropical and Subtropical Grasslands, Savannas a...  0.217699
#                  Tundra                                                   NaN
# Isoptera         Boreal Forests/Taiga                                     NaN
#                  Crops                                               0.246978
#                  Deserts and Xeric Shrublands                        0.976220
#                  Mediterranean Forests, Woodlands and Scrub          0.558391
#                  Pasture                                             0.310974
#                  Temperate Forests                                   0.637986
#                  Temperate Grasslands, Savannas and Shrublands       0.999146
#                  Tropical and Subtropical Forests                    0.229149
#                  Tropical and Subtropical Grasslands, Savannas a...  0.336512
#                  Tundra                                                   NaN
# Other            Boreal Forests/Taiga                                0.236342
#                  Crops                                               0.415005
#                  Pasture                                             0.270267
#                  Temperate Forests                                   0.173005
#                  Temperate Grasslands, Savannas and Shrublands       0.338296
#                  Tropical and Subtropical Forests                    0.289113
#                  Tropical and Subtropical Grasslands, Savannas a...  0.679597
#                  Tundra                                              0.556388
#
#                                                                             N
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                0.050801
#                  Crops                                               0.072996
#                  Deserts and Xeric Shrublands                        1.612282
#                  Mediterranean Forests, Woodlands and Scrub          0.154331
#                  Pasture                                             0.327629
#                  Temperate Forests                                   0.059446
#                  Temperate Grasslands, Savannas and Shrublands       0.063123
#                  Tropical and Subtropical Forests                    0.048760
#                  Tropical and Subtropical Grasslands, Savannas a...  0.026982
#                  Tundra                                              0.229890
# Collembola       Boreal Forests/Taiga                                0.044830
#                  Crops                                               0.159924
#                  Deserts and Xeric Shrublands                        5.017060
#                  Mediterranean Forests, Woodlands and Scrub          0.184996
#                  Pasture                                             3.036905
#                  Temperate Forests                                   0.164361
#                  Temperate Grasslands, Savannas and Shrublands       0.102249
#                  Tropical and Subtropical Forests                    0.281754
#                  Tropical and Subtropical Grasslands, Savannas a...  0.161941
#                  Tundra                                              0.099953
# Formicidae       Boreal Forests/Taiga                                0.390134
#                  Crops                                               0.124773
#                  Deserts and Xeric Shrublands                        0.085643
#                  Mediterranean Forests, Woodlands and Scrub          0.025641
#                  Pasture                                             0.081415
#                  Temperate Forests                                   0.034866
#                  Temperate Grasslands, Savannas and Shrublands       0.022519
#                  Tropical and Subtropical Forests                    0.120159
#                  Tropical and Subtropical Grasslands, Savannas a...  0.010863
#                  Tundra                                                   inf
# Isoptera         Boreal Forests/Taiga                                     inf
#                  Crops                                               0.018146
#                  Deserts and Xeric Shrublands                        0.040004
#                  Mediterranean Forests, Woodlands and Scrub          0.006906
#                  Pasture                                             0.036407
#                  Temperate Forests                                   0.016256
#                  Temperate Grasslands, Savannas and Shrublands       0.002848
#                  Tropical and Subtropical Forests                    0.034528
#                  Tropical and Subtropical Grasslands, Savannas a...  0.020505
#                  Tundra                                                   inf
# Other            Boreal Forests/Taiga                                0.059367
#                  Crops                                               0.007957
#                  Pasture                                             0.019457
#                  Temperate Forests                                   0.029095
#                  Temperate Grasslands, Savannas and Shrublands       0.016066
#                  Tropical and Subtropical Forests                    0.031180
#                  Tropical and Subtropical Grasslands, Savannas a...  0.024963
#                  Tundra                                              0.217655

# %%
#Compare the minimum values (~~~ remove later)
soil_biome_mean_std_boot.div(soil_biome_means_G.Min+1e-5, axis=0)
# Out:
#                                                                         mean  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                1.47894
#                  Crops                                                1.6231
#                  Deserts and Xeric Shrublands                        2.13344
#                  Mediterranean Forests, Woodlands and Scrub          11.4352
#                  Pasture                                             16.4078
#                  Temperate Forests                                    2.4451
#                  Temperate Grasslands, Savannas and Shrublands       2.48812
#                  Tropical and Subtropical Forests                    1.46633
#                  Tropical and Subtropical Grasslands, Savannas a...   2.7588
#                  Tundra                                              1.93801
# Collembola       Boreal Forests/Taiga                                3.43836
#                  Crops                                               1.47539
#                  Deserts and Xeric Shrublands                        2.34462
#                  Mediterranean Forests, Woodlands and Scrub          1.48641
#                  Pasture                                             1078.38
#                  Temperate Forests                                   2.63071
#                  Temperate Grasslands, Savannas and Shrublands       2.26954
#                  Tropical and Subtropical Forests                    1.39002
#                  Tropical and Subtropical Grasslands, Savannas a...  1.08635
#                  Tundra                                              3.16991
# Formicidae       Boreal Forests/Taiga                                3.33072
#                  Crops                                               2.53917
#                  Deserts and Xeric Shrublands                        2.39475
#                  Mediterranean Forests, Woodlands and Scrub                1
#                  Pasture                                             1.32825
#                  Temperate Forests                                   12.8828
#                  Temperate Grasslands, Savannas and Shrublands        4.2359
#                  Tropical and Subtropical Forests                    4.01179
#                  Tropical and Subtropical Grasslands, Savannas a...  1.27765
#                  Tundra                                                    0
# Isoptera         Boreal Forests/Taiga                                      0
#                  Crops                                               2.98781
#                  Deserts and Xeric Shrublands                        40.9804
#                  Mediterranean Forests, Woodlands and Scrub          2.34536
#                  Pasture                                              9.7942
#                  Temperate Forests                                   17.6691
#                  Temperate Grasslands, Savannas and Shrublands       1162.24
#                  Tropical and Subtropical Forests                    3.88859
#                  Tropical and Subtropical Grasslands, Savannas a...  2.42603
#                  Tundra                                                    0
# Other            Boreal Forests/Taiga                                2.73724
#                  Crops                                               1.70996
#                  Pasture                                             3.40177
#                  Temperate Forests                                   1.57592
#                  Temperate Grasslands, Savannas and Shrublands       3.01889
#                  Tropical and Subtropical Forests                    4.78647
#                  Tropical and Subtropical Grasslands, Savannas a...    3.099
#                  Tundra                                              2.95914
#
#                                                                          2.5%  \
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                 1.00173
#                  Crops                                               0.729731
#                  Deserts and Xeric Shrublands                        0.840859
#                  Mediterranean Forests, Woodlands and Scrub           2.82754
#                  Pasture                                             0.903218
#                  Temperate Forests                                    1.53506
#                  Temperate Grasslands, Savannas and Shrublands        1.45193
#                  Tropical and Subtropical Forests                    0.760964
#                  Tropical and Subtropical Grasslands, Savannas a...         1
#                  Tundra                                               1.25999
# Collembola       Boreal Forests/Taiga                                0.783515
#                  Crops                                               0.860297
#                  Deserts and Xeric Shrublands                        0.431126
#                  Mediterranean Forests, Woodlands and Scrub          0.785912
#                  Pasture                                                    0
#                  Temperate Forests                                    1.43243
#                  Temperate Grasslands, Savannas and Shrublands         1.3461
#                  Tropical and Subtropical Forests                    0.827482
#                  Tropical and Subtropical Grasslands, Savannas a...  0.999999
#                  Tundra                                                1.5447
# Formicidae       Boreal Forests/Taiga                                0.999994
#                  Crops                                                1.01754
#                  Deserts and Xeric Shrublands                        0.416308
#                  Mediterranean Forests, Woodlands and Scrub                 1
#                  Pasture                                             0.756334
#                  Temperate Forests                                   0.821679
#                  Temperate Grasslands, Savannas and Shrublands       0.728229
#                  Tropical and Subtropical Forests                     1.09506
#                  Tropical and Subtropical Grasslands, Savannas a...   0.82375
#                  Tundra                                                     0
# Isoptera         Boreal Forests/Taiga                                       0
#                  Crops                                                1.63776
#                  Deserts and Xeric Shrublands                         0.24215
#                  Mediterranean Forests, Woodlands and Scrub          0.249536
#                  Pasture                                              4.59078
#                  Temperate Forests                                   0.278736
#                  Temperate Grasslands, Savannas and Shrublands       0.999983
#                  Tropical and Subtropical Forests                     2.45826
#                  Tropical and Subtropical Grasslands, Savannas a...   1.25736
#                  Tundra                                                     0
# Other            Boreal Forests/Taiga                                 1.48534
#                  Crops                                               0.624468
#                  Pasture                                              1.51219
#                  Temperate Forests                                    1.08644
#                  Temperate Grasslands, Savannas and Shrublands        1.22631
#                  Tropical and Subtropical Forests                      2.0471
#                  Tropical and Subtropical Grasslands, Savannas a...  0.388626
#                  Tundra                                              0.931217
#
#                                                                        97.5%
# aggregated taxon aggregated biome
# Acari            Boreal Forests/Taiga                                1.98299
#                  Crops                                               3.02717
#                  Deserts and Xeric Shrublands                        3.35057
#                  Mediterranean Forests, Woodlands and Scrub          25.4942
#                  Pasture                                              42.771
#                  Temperate Forests                                   3.59172
#                  Temperate Grasslands, Savannas and Shrublands       3.72965
#                  Tropical and Subtropical Forests                    2.24425
#                  Tropical and Subtropical Grasslands, Savannas a...  4.56754
#                  Tundra                                              2.73813
# Collembola       Boreal Forests/Taiga                                7.67365
#                  Crops                                               2.39617
#                  Deserts and Xeric Shrublands                        5.23907
#                  Mediterranean Forests, Woodlands and Scrub          2.35794
#                  Pasture                                             3236.71
#                  Temperate Forests                                    4.3824
#                  Temperate Grasslands, Savannas and Shrublands       3.53045
#                  Tropical and Subtropical Forests                    2.24138
#                  Tropical and Subtropical Grasslands, Savannas a...  1.17201
#                  Tundra                                              5.46932
# Formicidae       Boreal Forests/Taiga                                5.65214
#                  Crops                                                4.5877
#                  Deserts and Xeric Shrublands                        4.94754
#                  Mediterranean Forests, Woodlands and Scrub                1
#                  Pasture                                             2.00254
#                  Temperate Forests                                   50.5081
#                  Temperate Grasslands, Savannas and Shrublands       10.5038
#                  Tropical and Subtropical Forests                    9.79005
#                  Tropical and Subtropical Grasslands, Savannas a...   1.8555
#                  Tundra                                                    0
# Isoptera         Boreal Forests/Taiga                                      0
#                  Crops                                               4.71147
#                  Deserts and Xeric Shrublands                        124.154
#                  Mediterranean Forests, Woodlands and Scrub          4.54331
#                  Pasture                                             16.9751
#                  Temperate Forests                                   38.8993
#                  Temperate Grasslands, Savannas and Shrublands       3066.91
#                  Tropical and Subtropical Forests                    5.65332
#                  Tropical and Subtropical Grasslands, Savannas a...   4.3275
#                  Tundra                                                    0
# Other            Boreal Forests/Taiga                                3.97498
#                  Crops                                               3.39975
#                  Pasture                                             5.36765
#                  Temperate Forests                                   2.15261
#                  Temperate Grasslands, Savannas and Shrublands       5.12445
#                  Tropical and Subtropical Forests                    7.87965
#                  Tropical and Subtropical Grasslands, Savannas a...    7.186
#                  Tundra                                              6.55398

# %% [markdown]
# 8. Prepare plot and read data for termites

# %%
def legend_without_duplicate_labels(ax,pos):
    handles, labels = ax.get_legend_handles_labels()
    mapping = [ ['Acari', 'Acari (Mites & Ticks)'],['Collembola', 'Collembola (Springtails)'],['Formicidae','Formicidae (Ants)'],['Isoptera', 'Isoptera (Termites)'],['Other','Others']]
    labels2 = [x.replace(subM[0], subM[1]) for x in labels for subM in mapping if subM[0] in x]
    unique = [(h, l) for i, (h, l) in enumerate(zip(handles, labels2)) if l not in labels2[:i]]
    unique = [unique[0],unique[1],unique[2], unique[3], unique[4]]      ## can be removed
    ax.legend(*zip(*unique),bbox_to_anchor=pos,loc = 'lower left', ncol=5)

# %%
Isoptera_data = pd.read_excel('data/IsopteraData.xlsx')

# %%
#Get the aggregated biome areas for use in the plot below
biome_area = pd.read_csv('data/aggregated biomes data.csv') # biomes area in units of m^2
biome_area1 = biome_area.groupby('aggregated biome 1')['area'].sum() #aggregate the biomes areas
biome_area1/1e12
# Out:
# aggregated biome 1
# Boreal Forests/Taiga                                            15.700
# Crops                                                           15.300
# Deserts and Xeric Shrublands                                    19.600
# Mediterranean Forests, Woodlands and Scrub                       1.620
# Pasture                                                         27.600
# Temperate Forests                                               10.760
# Temperate Grasslands, Savannas and Shrublands                    5.430
# Tropical and Subtropical Forests                                17.643
# Tropical and Subtropical Grasslands, Savannas and Shrublands    10.400
# Tundra                                                           7.490
# Name: area, dtype: float64

# %%
r = soil_site_data_mass_all.reset_index().rename(columns={'mass_G':'numerical value'}) #'numerical value' is the column being used later

#Sort according to biomes total mean biomass, in a descending order
sorter = soil_biome_means_G.reset_index().groupby('aggregated biome').sum().sort_values(by='Mean',ascending=False).index
sorterIndex = dict(zip(sorter, range(len(sorter))))
r['sorting_biomes'] = r['aggregated biome'].map(sorterIndex)
r.sort_values(['sorting_biomes'],ascending = True, inplace = True)
r.drop('sorting_biomes', 1, inplace = True)

original_biomes = r['aggregated biome'].unique()
transdict = {'Boreal Forests/Taiga': 'Boreal\nForests/\nTaiga\n(15.7M km$^2$)',
             'Crops':'Crops\n(15.3M km$^2$)',
             'Deserts and Xeric Shrublands':'Deserts\nand Xeric\nShrublands\n(19.6M km$^2$)',
             'Mediterranean Forests, Woodlands and Scrub':'Mediterranean\nForests,\nWoodlands\nand Scrub\n(1.6M km$^2$)',
             'Pasture':'Pasture\n(27.6M km$^2$)',
           'Temperate Forests':'Temperate\nForests\n(10.8M km$^2$)',
           'Temperate Grasslands, Savannas and Shrublands':'Temperate\nGrasslands,\nSavannas and\nShrublands\n(5.4M km$^2$)',
           'Tropical and Subtropical Forests':'Tropical and\nSubtropical\nForests\n(17.6M km$^2$)',
           'Tropical and Subtropical Grasslands, Savannas and Shrublands':'Tropical and\nSubtropical\nGrasslands,\nSavannas and\nShrublands\n(10.4M km$^2$)',
           'Tundra':'Tundra\n(7.5M km$^2$)'
            }

print_biomes = [transdict[biome] for biome in original_biomes]
r4 = r.replace(to_replace=original_biomes,value=print_biomes)
r4 = r4.loc[r4['numerical value']>=0] ###

bins = np.logspace(-1,np.log10(r4['numerical value'].max()),20)
bins = np.insert(bins,0,-0.1) #add the point -0.1 to the beginning of the bins array
#bins = np.logspace(r4['numerical value'].min(),r4['numerical value'].max(),20)   
t = r4.groupby(['aggregated biome','aggregated taxon'])['numerical value'].apply(lambda x: pd.cut(x,bins=bins).value_counts()/len(x)).reset_index()
y = t.groupby(['aggregated biome','aggregated taxon'])['numerical value'].apply(np.max).reset_index()
t3 = t.merge(y,left_on=['aggregated biome','aggregated taxon'],right_on=['aggregated biome','aggregated taxon'])
t3['val'] = t3['numerical value_x']/t3['numerical value_y']


Isoptra = Isoptera_data.replace(to_replace=original_biomes,value=print_biomes)


fig,ax=plt.subplots(figsize=[12,5]) #[11,4])

fine_loc = pd.Series([-0.4,-0.2,0,0.2,0.4],index=['Acari','Collembola','Formicidae','Isoptera','Other'])
col_arr = ['#4285F4','#7CBB00','#FFBB00','#f44336','#9e59b3']

def print_data(x):
    col_map = pd.Series(col_arr,index=['Acari','Collembola','Formicidae','Isoptera','Other'])
    fine_loc = pd.Series([-0.4,-0.2,0,0.2,0.4],index=['Acari','Collembola','Formicidae','Isoptera','Other'])
    col = col_map.loc[x['aggregated taxon'].values[0]]
    locs = pd.Series(range(0,2*len(r4['aggregated biome'].unique()),2),index=r4['aggregated biome'].unique())
    xloc = locs.loc[x['aggregated biome'].values[0]] + fine_loc.loc[x['aggregated taxon'].values[0]]
    if x['val'].values[0] == 1:
        lab = x['aggregated taxon'].values[0]
    else:
        lab=None
    plt.bar(x=xloc,
            height=x['level_2'].values[0].right-x['level_2'].values[0].left,
            width=0.17,
            bottom=x['level_2'].values[0].left,
            log=True,color=col,alpha=x['val'].values[0],
            label=lab,
            zorder=1
           )
    ax.set_yscale('symlog',linthreshy=0.1)
    
    
def print_mean_median(x):
    locs = pd.Series(range(0,2*len(r4['aggregated biome'].unique()),2),index=r4['aggregated biome'].unique())
    xloc = locs.loc[x['aggregated biome'].values[0]] + fine_loc.loc[x['aggregated taxon'].values[0]]
    Mean = x['numerical value'].mean()
    SEM = x['numerical value'].sem()
    Y = (Mean, Mean - SEM , Mean + SEM)
    plt.scatter(x=xloc,y=Y[0],marker='.',c='k',s=40,zorder=3)
    plt.scatter(x=xloc,y=Y[1],marker='_',c='k',s=40,zorder=3)
    plt.scatter(x=xloc,y=Y[2],marker='_',c='k',s=40,zorder=3)
    
    
def print_mean_log(x):
    locs = pd.Series(range(0,2*len(r4['aggregated biome'].unique()),2),index=r4['aggregated biome'].unique())
    xloc = locs.loc[x['aggregated biome'].values[0]] + fine_loc.loc[x['aggregated taxon'].values[0]]
    Y = LogMean(x['numerical value'],kk = 1,scale = Scale)
    plt.scatter(x=xloc,y= Y[0],marker='o',c='#941751', alpha=0.5,s=40,zorder=4)
    plt.scatter(x=xloc,y= Y[1],marker='2',c='#941751', alpha=0.5,s=40,zorder=4)
    plt.scatter(x=xloc,y= Y[2],marker='1',c='#941751', alpha=0.5,s=40,zorder=4)
    plt.scatter(x=xloc,y= (Y[0]+x['numerical value'].mean())/2,marker='4',c='m', alpha=1,s=40,zorder=4)
    

def print_combined_mean(x):
    locs = pd.Series(range(0,2*len(r4['aggregated biome'].unique()),2),index=r4['aggregated biome'].unique())
    xloc = locs.loc[x['aggregated biome'].values[0]] + fine_loc.loc[x['aggregated taxon'].values[0]]
    Y = calc_mean(x['numerical value'])+0.08
    plt.scatter(x=xloc,y= Y,marker='.' ,c='k', alpha=1,s=100,zorder=3)
    plt.scatter(x=xloc,y= Y,marker='.' ,c='#EBEBEB', alpha=1,s=15,zorder=3)  
    
def print_mean_alt(x):
    locs = pd.Series(range(0,2*len(r4['aggregated biome'].unique()),2),index=r4['aggregated biome'].unique())
    xloc = locs.loc[x['aggregated biome'].values[0]] + fine_loc.loc[x['aggregated taxon'].values[0]]
    Y = Mean_alt(x['numerical value'])[0]+0.08
    L = Mean_alt(x['numerical value'])[1]
    U = Mean_alt(x['numerical value'])[2]
    plt.scatter(x=xloc,y= Y,marker='.' ,c='r', alpha=1,s=100,zorder=3)
    plt.scatter(x=xloc,y= Y,marker='.' ,c='y', alpha=1,s=15,zorder=3)  
    plt.scatter(x=xloc,y= L,marker='_' ,c='r', alpha=1,s=15,zorder=3)  
    plt.scatter(x=xloc,y= U,marker='_' ,c='r', alpha=1,s=15,zorder=3)  

def print_combined_errors(x):
    locs = pd.Series(range(0,2*len(r4['aggregated biome'].unique()),2),index=r4['aggregated biome'].unique())
    xloc = locs.loc[x['aggregated biome'].values[0]] + fine_loc.loc[x['aggregated taxon'].values[0]]
    Y1 = calc_min(x['numerical value'])
    Y2 = calc_max(x['numerical value'])
    plt.scatter(x=xloc,y=Y1 ,marker='_',c='k',s=40,zorder=3)
    plt.scatter(x=xloc,y=Y2 ,marker='_',c='k',s=40,zorder=3)
    
#Print fine average of Isoptera
def print_mean_Isoptera(x):
    fine_loc_Iso = 0.2;
    locs = pd.Series(range(0,2*len(r4['aggregated biome'].unique()),2),index=r4['aggregated biome'].unique())
    xloc = locs.loc[x['aggregated biome'].values[0]] + fine_loc_Iso
    plt.scatter(x=xloc,y=x['Mid estimate'],marker='*',c='k', alpha=1,s=40,zorder=4)
    plt.scatter(x=xloc,y=x['Mid estimate'],marker='*',c='#EBEBEB', alpha=1,s=15,zorder=4)
    plt.scatter(x=xloc,y=x['Low estimate'],marker='+',c='k', alpha=1,s=40,zorder=4)
    plt.scatter(x=xloc,y=x['High estimate'],marker='+',c='k', alpha=1,s=40,zorder=4)


def print_bootstrap(x):
    locs = pd.Series(range(0,2*len(r4['aggregated biome'].unique()),2),index=r4['aggregated biome'].unique())
    x = x.replace(to_replace=original_biomes,value=print_biomes)
    xloc = locs.loc[x['aggregated biome'].values[0]] + fine_loc.loc[x['aggregated taxon'].values[0]]
    Y = x['mean']
    L = x['2.5%']
    U = x['97.5%']
    plt.scatter(x=xloc,y= Y,marker='.' ,c='#153B80', alpha=1,s=100,zorder=3)
    plt.scatter(x=xloc,y= Y,marker='.' ,c='#10DC00', alpha=1,s=15,zorder=3)  
    plt.scatter(x=xloc,y= L,marker='+' ,c='k', alpha=1,s=15,zorder=3)  
    plt.scatter(x=xloc,y= U,marker='+' ,c='k', alpha=1,s=15,zorder=3) 
#    plt.scatter(x=xloc,y= L,marker='_' ,c='#10DC00', alpha=0.9,s=10,zorder=3)  
#    plt.scatter(x=xloc,y= U,marker='_' ,c='#10DC00', alpha=0.9,s=10,zorder=3) 
   

    
#     if x['val'].values[0] >0:
#         plt.plot([xloc-0.17/2,xloc+0.17/2],[x['level_2'].values[0].right,x['level_2'].values[0].right],color='k',linewidth=0.7,alpha=1)
for i in range(0,2*len(r4['aggregated biome'].unique()),2):    
    plt.plot([i-0.7,i+0.7],[0.05,0.05],'k')   #plot lines for labels
    plt.plot([i-0.7,i+0.7],[1e-1,1e-1],'k:',alpha = 0.8)    #plot dotted lines for breaking points "detection limit"

#Plot data
ax = t3.groupby(['aggregated biome','aggregated taxon','level_2']).apply(print_data)
ax = plt.gca()
ax.set_xticks(range(0,2*len(r4['aggregated biome'].unique()),2))
ax.set_xticklabels(r4['aggregated biome'].unique())
ax.get_label()
ax.set_ylabel('Dry Biomass Density [mg/m$^2$]')
#plt.legend()
ax.set_ylim([0.05,1e5])
ax.set_xlim([-1,19])
legend_without_duplicate_labels(ax,(0.007,0.9)) #(0.98,0))
sb.despine(top=True, bottom=True, right=True)
#r4.groupby(['aggregated biome','aggregated taxon']).apply(print_mean_median)##
#r4.groupby(['aggregated biome','aggregated taxon']).apply(print_mean_log)##
#Isoptra.groupby(['aggregated biome','aggregated taxon']).apply(print_mean_Isoptera)##
#r4.groupby(['aggregated biome','aggregated taxon']).apply(print_combined_errors)##
r4.groupby(['aggregated biome','aggregated taxon']).apply(print_combined_mean)###
#r4.groupby(['aggregated biome','aggregated taxon']).apply(print_mean_alt)###
soil_biome_mean_std_boot.reset_index().groupby(['aggregated biome','aggregated taxon']).apply(print_bootstrap)###

ax.text(0.007, 0.135, 'Detection Limit', transform=ax.transAxes, fontsize=9,
        verticalalignment='top', bbox=None, color = 'k', alpha = 0.95)

plt.tight_layout()


#Save:
#plt.savefig('results/fig_mass_dens_all_G.svg',dpi=300) ##
#plt.savefig('results/fig_mass_dens_all_G.pdf',dpi=300) ##
#plt.savefig('results/fig_mass_dens_all_G.png',dpi=600) ##

# %% [markdown]
# 9. Calculate the total population in soils

# %%
soil_biome_Mean = soil_biome_means_G  #Change _G or _B for global or biome-level ind. mass, where applicable

##--Change termites means to carful estimates--
#Isoptera_data = pd.read_excel('data/IsopteraData.xlsx')
#Isoptera_data.set_index('aggregated biome' , inplace = True)
#soil_biome_Mean.Mean.Isoptera = Isoptera_data.loc[:,'Mid estimate']
#soil_biome_Mean.Min.Isoptera = np.minimum(Isoptera_data.loc[:,'Low estimate'], soil_biome_Mean.Min.Isoptera)# Isoptera_data.loc[:,'Low estimate']
#soil_biome_Mean.Max.Isoptera = np.maximum(Isoptera_data.loc[:,'High estimate'], soil_biome_Mean.Max.Isoptera)#Isoptera_data.loc[:,'High estimate']


biome_area = pd.read_csv('data/aggregated biomes data.csv') # import biomes area in units of m^2
biome_area1 = biome_area.groupby('aggregated biome 1')['area'].sum() #aggregate the biomes areas
soil_biome_Mean1 = soil_biome_Mean.merge(pd.DataFrame(biome_area1),left_on='aggregated biome',right_index=True) #add the total areas of the aggregated biomes to the means DF
soil_biome_Mean1.loc[:,'Total'] = (soil_biome_Mean1.loc[:,'Mean']*soil_biome_Mean1.loc[:,'area']).values #total population per biome, in units of mg. (use 1e18 to convert to Gt)
soil_biome_Mean1.loc[:,'Total_high'] = (soil_biome_Mean1.loc[:,'Max']*soil_biome_Mean1.loc[:,'area']).values #total population per biome, in units of mg. (use 1e18 to convert to Gt)
soil_biome_Mean1.loc[:,'Total_low'] = (soil_biome_Mean1.loc[:,'Min']*soil_biome_Mean1.loc[:,'area']).values #total population per biome, in units of mg. (use 1e18 to convert to Gt)

total_soil = soil_biome_Mean1.loc[:,['Total_high','Total','Total_low']].sum()/1e15

print('Using combined mean:')
print('total high estimate is: ' + "{:.0f}".format(total_soil['Total_high']) + ' Mt dry biomass in soils')
print('total mid estimate is: ' + "{:.0f}".format(total_soil['Total'] ) + ' Mt dry biomass in soils')
print('total low estimate is: ' + "{:.0f}".format(total_soil['Total_low'])  + ' Mt dry biomass in soils')
# Out:
# Using combined mean:
# total high estimate is: 317 Mt dry biomass in soils
# total mid estimate is: 161 Mt dry biomass in soils
# total low estimate is: 83 Mt dry biomass in soils

# %%
soil_biome_Mean = soil_biome_mean_std_boot  #repeat for bootstrapped data

biome_area = pd.read_csv('data/aggregated biomes data.csv') # biomes area in units of m^2
biome_area1 = biome_area.groupby('aggregated biome 1')['area'].sum() #aggregate the biomes areas
soil_biome_Mean2 = soil_biome_Mean.merge(pd.DataFrame(biome_area1),left_on='aggregated biome',right_index=True) #add the total areas of the aggregated biomes to the means DF
soil_biome_Mean2.loc[:,'Total'] = (soil_biome_Mean2.loc[:,'mean']*soil_biome_Mean2.loc[:,'area']).values #total population per biome, in units of mg. (use 1e18 to convert to Gt)
soil_biome_Mean2.loc[:,'Total_high'] = (soil_biome_Mean2.loc[:,'97.5%']*soil_biome_Mean2.loc[:,'area']).values #total population per biome, in units of mg. (use 1e18 to convert to Gt)
soil_biome_Mean2.loc[:,'Total_low'] = (soil_biome_Mean2.loc[:,'2.5%']*soil_biome_Mean2.loc[:,'area']).values #total population per biome, in units of mg. (use 1e18 to convert to Gt)

total_soil = soil_biome_Mean2.loc[:,['Total_high','Total','Total_low']].sum()/1e15

#Taking the sum of resampled extremes (corresponding to 95% CI for the various biomes), the biomass in soil is i nthe following range:
print('Using bootstrapping:')
print('total high estimate is: ' + "{:.0f}".format(total_soil['Total_high']) + ' Mt dry biomass in soils')
print('total mid estimate is: ' + "{:.0f}".format(total_soil['Total'] ) + ' Mt dry biomass in soils')
print('total low estimate is: ' + "{:.0f}".format(total_soil['Total_low'])  + ' Mt dry biomass in soils')
# Out:
# Using bootstrapping:
# total high estimate is: 423 Mt dry biomass in soils
# total mid estimate is: 238 Mt dry biomass in soils
# total low estimate is: 112 Mt dry biomass in soils

# %%
#plot distribution of the total biomass using bootstrapping
#Yinon implementation
biome_area = pd.read_csv('data/aggregated biomes data.csv') # biomes area in units of m^2
biome_area1 = biome_area.groupby('aggregated biome 1')['area'].sum() #aggregate the biomes areas

soil_means_dist_tot = soil_means_dist.merge(pd.DataFrame(biome_area1),left_on='aggregated biome',right_index=True) #add the total areas of the aggregated biomes 
soil_means_dist_tot.loc[:,'values'] = (soil_means_dist_tot['values']*soil_means_dist_tot['area'])
soil_means_dist_tot.drop('area',axis='columns',inplace=True)

taxa = soil_means_dist.index.get_level_values(0).unique()
biomes = soil_means_dist.index.get_level_values(1).unique()

start_time = time.time()

N_total_dist = 10000
total_soil_dist_taxa = soil_means_dist_tot.apply(lambda x: pd.Series(random_from_cdf(x['cdf'],x['values'],N_total_dist),index=range(N_total_dist)),axis=1)
#total_soil_dist_taxa = total_soil_dist_taxa.sum(axis=0)
#total_soil_dist_taxa = pd.DataFrame(index = taxa, columns=['sum_array']) #initialize 

#for taxon in taxa:
#    total_soil_dist_taxa.loc[taxon, 'sum_array'] = np.zeros(N_total_dist) #initialize the array for a certail taxon group
#    for ii in range(N_total_dist):
#        for biome in biomes:
#            if (taxon,biome) in soil_means_dist.index:
#                cdf, values = soil_means_dist_tot.loc[taxon,biome]
#                total_soil_dist_taxa.loc[taxon, 'sum_array'][ii] += random_from_cdf(cdf,values,1)
            
                
total_soil_dist_taxa /= 1e15 

end_time = time.time()
print('Time:' + '{:.2f}'.format(end_time-start_time) + ' seconds')    

plt.hist(total_soil_dist_taxa.sum(axis=0),40,alpha=0.8)
# Out:
# Time:2.72 seconds
# (array([  5.,   4.,   7.,  22.,  33.,  68., 115., 193., 238., 324., 381.,
#         484., 586., 685., 731., 773., 776., 694., 678., 590., 549., 455.,
#         374., 301., 248., 208., 140., 116.,  68.,  47.,  36.,  27.,  12.,
#          13.,   8.,   3.,   3.,   1.,   3.,   1.]),
#  array([176.77837267, 180.49251063, 184.20664859, 187.92078655,
#         191.63492451, 195.34906247, 199.06320043, 202.77733839,
#         206.49147635, 210.20561431, 213.91975228, 217.63389024,
#         221.3480282 , 225.06216616, 228.77630412, 232.49044208,
#         236.20458004, 239.918718  , 243.63285596, 247.34699392,
#         251.06113188, 254.77526985, 258.48940781, 262.20354577,
#         265.91768373, 269.63182169, 273.34595965, 277.06009761,
#         280.77423557, 284.48837353, 288.20251149, 291.91664945,
#         295.63078742, 299.34492538, 303.05906334, 306.7732013 ,
#         310.48733926, 314.20147722, 317.91561518, 321.62975314,
#         325.3438911 ]),
#  <a list of 40 Patch objects>)

# %%
tot_biomass_taxon = total_soil_dist_taxa.groupby('aggregated taxon').sum().T
tot_biomass_taxon.plot.hist(bins=40, alpha=0.8,colors=col_arr)
# Out:
# /Users/Yuvalr/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:203: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   "'colors' is being deprecated. Please use 'color'"

# %%
tot_biomass_biome = total_soil_dist_taxa.groupby('aggregated biome').sum().T
tot_biomass_biome.mean()
# Out:
# aggregated biome
# Boreal Forests/Taiga                                            18.471871
# Crops                                                           42.363292
# Deserts and Xeric Shrublands                                     2.693472
# Mediterranean Forests, Woodlands and Scrub                       1.187147
# Pasture                                                         45.331185
# Temperate Forests                                               36.626526
# Temperate Grasslands, Savannas and Shrublands                   12.589601
# Tropical and Subtropical Forests                                53.359076
# Tropical and Subtropical Grasslands, Savannas and Shrublands    21.136405
# Tundra                                                           5.147287
# dtype: float64

# %% [markdown]
# total_soil_dist_taxa.plot.hist(bins=40, alpha=0.8,colors=col_arr)

# %%
def ext_stats(x,round_bool=False):
    if round_bool:
        return np.array([round(np.mean(x)), round(np.percentile(x,2.5)), round(np.percentile(x,97.5))])
    else:
        return np.array([np.mean(x), np.percentile(x,2.5), np.percentile(x,97.5)])
        
#print(tot_biomass_taxon.apply(lambda x: round(np.mean(x))))
#tot_biomass_taxon.apply(lambda x: np.percentile(x,[2.5,97.5]))
tot_biomass_taxon.apply(lambda x: ext_stats(x,True))
# Out:
# aggregated taxon  Acari  Collembola  Formicidae  Isoptera  Other
# 0                  26.0        16.0        28.0      98.0   71.0
# 1                  21.0         9.0        16.0      74.0   52.0
# 2                  31.0        26.0        52.0     125.0   93.0

# %%
ext_stats(total_soil_dist_taxa.sum(axis=0),round_bool=True)
# Out:
# array([239., 203., 280.])

# %%
soil_biome_Mean2.groupby('aggregated taxon')['Total_high','Total','Total_low'].sum()/1e15
# Out:
#                   Total_high      Total  Total_low
# aggregated taxon
# Acari              38.993679  25.765622  15.073666
# Collembola         31.027330  16.086991   6.348637
# Formicidae         67.546914  27.197949   9.158507
# Isoptera          165.634844  98.263033  49.163598
# Other             119.563117  71.157508  32.411296

# %%
#summing as an error, the biomass margins are less than 50Mt (here: bootstrap)
print(sum_error(soil_biome_Mean2.loc[:,['Total_high']].values- soil_biome_Mean2.loc[:,['Total']].values)/1e15)
print(sum_error(soil_biome_Mean2.loc[:,['Total_low']].values- soil_biome_Mean2.loc[:,['Total']].values)/1e15)
# Out:
# 45.669538995012374
# 29.803266190678848

# %%
#summing as an error, the biomass margins are less than 50Mt (here: combined mean)
print(sum_error(soil_biome_Mean1.loc[:,['Total_high']].values- soil_biome_Mean1.loc[:,['Total']].values)/1e15)
print(sum_error(soil_biome_Mean1.loc[:,['Total_low']].values- soil_biome_Mean1.loc[:,['Total']].values)/1e15)
# Out:
# 38.762826871289576
# 20.99112507927599

# %%
plt.hist((soil_biome_Mean2.loc[:,['Total_high']].values- soil_biome_Mean2.loc[:,['Total']].values)/(soil_biome_Mean2.loc[:,['Total']].values+1))
# Out:
# (array([ 5., 14., 13.,  3.,  7.,  3.,  2.,  0.,  0.,  1.]),
#  array([0.0, 0.2920578038145918, 0.5841156076291836, 0.8761734114437754,
#         1.1682312152583672, 1.460289019072959, 1.7523468228875507,
#         2.0444046267021427, 2.3364624305167343, 2.628520234331326,
#         2.920578038145918], dtype=object),
#  <a list of 10 Patch objects>)

# %%
#difference between the two methods (30-50% higher in the bootstrap)
total_soil1 = soil_biome_Mean1.loc[:,['Total_high','Total','Total_low']].sum()/1e15
total_soil2 = soil_biome_Mean2.loc[:,['Total_high','Total','Total_low']].sum()/1e15

total_soil2/total_soil1
# Out:
# Total_high    1.333242
# Total         1.482573
# Total_low     1.349872
# dtype: float64

# %%
soil_taxon_tot = soil_biome_Mean1.groupby('aggregated taxon')['Total_high','Total','Total_low'].sum()
print(soil_taxon_tot['Total_high']/soil_taxon_tot['Total'])
print(soil_taxon_tot['Total_low']/soil_taxon_tot['Total'])
print(soil_taxon_tot['Total']/1e15)
print(soil_taxon_tot['Total'].sum()/1e15)
# Out:
# aggregated taxon
# Acari         1.645944
# Collembola    2.085504
# Formicidae    2.039372
# Isoptera      2.134268
# Other         1.850868
# dtype: float64
# aggregated taxon
# Acari         0.671853
# Collembola    0.527395
# Formicidae    0.592461
# Isoptera      0.384426
# Other         0.585348
# dtype: float64
# aggregated taxon
# Acari         19.806976
# Collembola    10.947247
# Formicidae    18.856838
# Isoptera      61.117599
# Other         50.120833
# Name: Total, dtype: float64
# 160.8494922080738

# %%
Labels=['Acari','Collembola','Formicidae','Isoptera','Other']

fig, (ax1,ax2,ax3) = plt.subplots(1, 3,figsize=[12,4])
fig.suptitle('Total soil population breakdown')

ax1.pie(((soil_biome_Mean1.groupby('aggregated taxon').Total.sum())/total_soil['Total']) , colors=col_arr, labels=Labels,autopct='%1.0f%%')
ax2.pie(((soil_biome_Mean1.groupby('aggregated taxon')['Total_low'].sum())/total_soil['Total_low']) , colors=col_arr, labels=Labels,autopct='%1.0f%%')
ax3.pie(((soil_biome_Mean1.groupby('aggregated taxon')['Total_high'].sum())/total_soil['Total_high']) , colors=col_arr, labels=Labels,autopct='%1.0f%%')

ax1.title.set_text('mid estimates')
ax2.title.set_text('low estimates')
ax3.title.set_text('high estimates')

plt.show()

plt.tight_layout()

#Save:
#fig.savefig('results/fig2a_all.svg', dpi=300)
#fig.savefig('results/fig2a_all.pdf', dpi=300)

# %%
#calculate data normalized according to area
mg_m2 = (soil_biome_Mean1.groupby('aggregated taxon').Total.sum()/biome_area1.sum())
mg_ind = soil_ratio_filt_full.loc[:,'Total average (mg/ind)']
num_m2 = mg_m2 / mg_ind

#num_m2.sum()
biome_area1.sum()/1e14
# Out:
# 1.31543

# %%
plt.rcParams.update({'font.size': 12}) #increase the font size here
plt.rc('text', usetex=False)


fig,ax1 = plt.subplots(1,2,figsize=[12,4],dpi=300)
ax1 = plt.subplot(1,2,1)
group_sum = (soil_biome_Mean1.groupby('aggregated taxon').Total.sum()/1e15)
group_colors = pd.Series(col_arr,index = group_sum.index)
new_index = ['Isoptera','Formicidae','Acari','Collembola','Other']
group_sum = group_sum.reindex(new_index)
group_colors = group_colors.reindex(new_index)
#group_sum.index = ['Isoptera\n(Termites)','Formicidae\n(Ants)','Acari\n(Mites & Ticks)','Collembola\n(Springtails)','Other']
group_sum.index = ['Isoptera\n(Termites)','Formicidae\n(Ants)','Acari\n(Mites & Ticks)','Collembola\n(Springtails)','Other']

group_colors.index = group_sum.index
#group_sum.sort_values(ascending=False,inplace=True)
#group_sum.sort_values(ascending=False).plot.bar(width = 0.6,color=group_colors.loc[group_sum.index],rot=0,ax=ax)
group_sum.plot.bar(width = 0.6,color=group_colors.loc[group_sum.index],rot=0,ax=ax1)
ax1.set_ylabel('Total Dry Biomass [Mt]')
plt.xticks(fontsize=10)

# (part1.groupby('aggregated taxon').Total.sum()/1e18).apply(lambda x: x.nominal_value)
ax2 = plt.subplot(1,2,2)
subphyla_sum = pd.read_csv('results/subphyla_sum.csv') #subphyla_sum = ((sp_soil_biome_means*area).groupby('sub-phylum').apply(np.nansum)/1e15)
subphyla_sum.index = subphyla_sum.iloc[:,0]
del subphyla_sum.index.name
subphyla_sum = subphyla_sum.iloc[:,1]
subphyla_colors = pd.Series(['#795548', '#4db6ac','#607d8b','#bdbdbd'],index = subphyla_sum.index)
#subphyla_sum.sort_values(ascending=False,inplace=True)
subphyla_sum.plot.bar(width = 0.5,color=subphyla_colors.loc[subphyla_sum.index],ax=ax2,rot=0)
plt.xticks(fontsize=10)

ax1.set_ylim([0,180])
ax2.set_ylim([0,180])
ax1.set(yticks=np.arange(0,200,50))
ax2.set(yticks=np.arange(0,200,50))


#ax.set_ylim([0,0.21])
#ax2.set_ylim([0,0.21])
#ax.set(yticks=np.arange(0,0.25,0.05))
#ax2.set(yticks=np.arange(0,0.25,0.05))
# ax.set_ylabel('Biomass [Gt]')
# plt.savefig('results/fig2b.svg', dpi=300)
#ax.text(-1,160,'A',fontdict={'size':20})
#ax2.text(-1,160,'B',fontdict={'size':20})
ax1.text(0.02,0.9,'A',fontdict={'size':20},transform = ax1.transAxes)
ax2.text(0.02,0.9,'B',fontdict={'size':20},transform = ax2.transAxes)
plt.tight_layout()

#plt.savefig('results/fig2.svg', dpi=300)
#plt.savefig('results/fig2.pdf', dpi=300)##
#plt.savefig('results/fig2.png', dpi=300)##

# plt.savefig('results/fig2b.svg', dpi=300)
# ((sp_soil_biome_means*area).groupby('sub-phylum').apply(np.nansum)/tot_sp.nominal_value)

plt.rcParams.update({'font.size': 10}) #decrease back the font size here

# %%
subphyla_sum = pd.read_csv('results/subphyla_sum.csv') #subphyla_sum = ((sp_soil_biome_means*area).groupby('sub-phylum').apply(np.nansum)/1e15)
subphyla_sum.index = subphyla_sum.iloc[:,0]
subphyla_sum = subphyla_sum.iloc[:,1]
subphyla_sum
# Out:
# Unnamed: 0
# Hexapoda       137.210509
# Chelicerata     21.389202
# Myriapoda       14.300360
# Crustacea        6.602141
# Name: 0, dtype: float64

# %% [markdown]
# Data in canopies and on surface is too scarse to use an effective mass, and we see from the population and the mass measurements that it'll not change the overall estimation much, hence  (??), and the sub-phyla division is too coarse to use it (the spread of individual masses is too large in this case).

# %% [markdown]
# 12. Calculate the overall total population, assuming places with no data has no individuals

# %% [markdown]
# overall_population = total_surface+total_canopy+total_soil
# overall_population

# %% [markdown]
# 13. Calculate and plot the total population per aggregated biome

# %%
#The total soil biomass calculated here (Gt), using both population and biomass data
Soil_mass = soil_biome_Mean1.loc[:,['Total_high','Total','Total_low']].groupby('aggregated biome').sum()/1e15
Soil_mass=Soil_mass.reset_index()
Soil_mass.insert(0, 'env', 'soil',True)

#Read the total biomass of canopy and surface and replace the soil biomass to the current estimation 
biome_totals_mass = pd.read_csv('results/table_biome_totals_mass.csv')
biome_totals_mass.loc[biome_totals_mass['env']=='soil'] = Soil_mass

biome_totals_pop = pd.read_csv('results/table_biome_totals_pop.csv')

def sort_by_index(x,sorted_indx):
    sorterIndex = dict(zip(sorted_indx, range(len(sorted_indx))))
    x['sorting_biomes'] = x.index.map(sorterIndex)
    x.sort_values(['sorting_biomes'],ascending = True, inplace = True)
    x.drop('sorting_biomes', 1, inplace = True)
    return x

def data4tot_plot(x):
    #rename labels for plot
    original_biomes = x['aggregated biome']
    transdict = {'Boreal Forests/Taiga': 'Boreal Forests',
             'Crops':'Crops',
             'Deserts and Xeric Shrublands':'Deserts',
             'Mediterranean Forests, Woodlands and Scrub':'Mediterranean',
             'Pasture':'Pasture',
           'Temperate Forests':'Temp. Forests',
           'Temperate Grasslands, Savannas and Shrublands':'Temp.\nGrasslands',
           'Tropical and Subtropical Forests':'Trop. Forests',
           'Tropical and Subtropical Grasslands, Savannas and Shrublands':'Trop.\nGrasslands',
           'Tundra':'Tundra'
            }
    print_biomes = [transdict[biome] for biome in original_biomes]    
    x['aggregated biome'] = print_biomes
    
    #total values
    x_tot = x.reset_index().pivot(index = 'aggregated biome' , columns = 'env', values='Total')    
    
    #sort by descending values
    sorter = x_tot.sum(axis=1).sort_values(ascending=False).index
    x_tot = sort_by_index(x_tot ,sorter )
    
    x['err_low'] = (x.loc[:,'Total']-x.loc[:,'Total_low'])
    x['err_high'] = (x.loc[:,'Total_high']-x.loc[:,'Total'])
    
    err_l = x.pivot(index = 'aggregated biome' , columns = 'env', values='err_low' ) 
    err_l = sort_by_index(err_l,x_tot.index)
    err_h = x.pivot(index = 'aggregated biome' , columns = 'env', values= 'err_high')
    err_h = sort_by_index(err_l,x_tot.index)
    
    err = []
    for col in err_l:  # Iterate over bar groups (represented as columns)
        err.append([err_l[col].values, err_h[col].values])    
        
    return x_tot , err


mass_tots, err_m = data4tot_plot(biome_totals_mass)
pop_tots, err_p= data4tot_plot(biome_totals_pop)


fig = plt.subplots(figsize=[12,4])
ax = plt.subplot(1,2,1)
mass_tots.plot.bar(yerr=err_m ,width = 0.8, color=['#008F00','#945200', '#FFD479' ],ax=ax,logy=True,stacked=False,rot=90,legend=False)
ax.set_ylabel('Total Dry Biomass [Mt]')
#ticklabels = ['Boreal Forest', 'Crops','Desert','Mediteranian', 'Pasture','Temp. Forest', 'Temp.\nGrassland', 'Trop. Forest','Trop.\nGrassland','Tundra']
#ax.xaxis.set_ticklabels(ticklabels)
ax.xaxis.label.set_visible(False)
#ax.set_ylim([0,100])
#ax.legend(loc = [1.01,0.7])
#ax.ticks

ax = plt.subplot(1,2,2)
mass_tots.plot.bar(width = 0.8, color=['#008F00','#945200', '#FFD479' ],ax=ax,logy=False,stacked=True)
ax.set_ylabel('Total Dry Biomass [Mt]')
#ax.xaxis.set_ticklabels(ticklabels)
ax.xaxis.label.set_visible(False)
#ax.set_ylim([0,100])
handles, labels = ax.get_legend_handles_labels()
ax.legend([handles[2],handles[1],handles[0]],[labels[2],labels[1],labels[0]],loc = [1.01,0.7])

plt.tight_layout()

#plt.savefig('results/fig_pop_biome_totsig_.svg', dpi=300)
#plt.savefig('results/fig_pop_biome_tots.pdf', dpi=300)##

# %%
plt.rcParams.update({'font.size': 12}) #increase the font size here

fig = plt.subplots(figsize=[12,8])


ax1 = plt.subplot(2,2,1)
mass_tots.plot.bar(width = 0.8, color=['#008F00','#945200', '#FFD479' ],ax=ax1,logy=False,stacked=True)
ax1.set_ylabel('Total Dry Biomass [Mt]')
#ax.xaxis.set_ticklabels(ticklabels)
x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)
ax1.set_ylim([0,45])
handles, labels = ax1.get_legend_handles_labels()

transdict = {'surface': 'Surface',
             'soil': 'Soil',
             'canopy': 'Canopy'
            }
Labels = [transdict[env] for env in labels]

ax1.legend([handles[2],handles[1],handles[0]],[Labels[2],Labels[1],Labels[0]],loc = [0.01,1.02],ncol=3,fontsize=14)
#ax1.legend([handles[2],handles[1],handles[0]],['Surface','Soil','Canopy'],loc = [0.01,1.02],ncol=3,fontsize=12)
ax1.text(0.01,0.91,'A',fontdict={'size':20},transform = ax1.transAxes)

ax2 = plt.subplot(2,2,2)
(pop_tots/1e18).plot.bar(width = 0.8, color=['#008F00','#945200', '#FFD479' ],ax=ax2,logy=False,stacked=True)
ax2.set_ylabel('Total Population [$10^{18}$]')
#ax.xaxis.set_ticklabels(ticklabels)
x_axis = ax2.axes.get_xaxis()
x_axis.set_visible(False)
ax2.set_ylim([0,3.1])
ax2.get_legend().remove()
ax2.text(0.01,0.91,'B',fontdict={'size':20},transform = ax2.transAxes)


ax3 = plt.subplot(2,2,3)
mass_tots.plot.bar(yerr=err_m ,width = 0.8, color=['#008F00','#945200', '#FFD479' ],ax=ax3,logy=True,stacked=False,rot=90,legend=False)
ax3.set_ylabel('Total Dry Biomass [Mt]')
#ticklabels = ['Boreal Forest', 'Crops','Desert','Mediteranian', 'Pasture','Temp. Forest', 'Temp.\nGrassland', 'Trop. Forest','Trop.\nGrassland','Tundra']
#ax.xaxis.set_ticklabels(ticklabels)
ax3.xaxis.label.set_visible(False)
#ax.set_ylim([0,100])
#ax.legend(loc = [1.01,0.7])
#ax.ticks
ax3.text(0.01,0.91,'C',fontdict={'size':20},transform = ax3.transAxes)

ax4 = plt.subplot(2,2,4)
pop_tots.plot.bar(yerr=err_p ,width = 0.8, color=['#008F00','#945200', '#FFD479' ],ax=ax4,logy=True,stacked=False,rot=90,legend=False)
ax4.set_ylabel('Total Population')
#ticklabels = ['Boreal Forest', 'Crops','Desert','Mediteranian', 'Pasture','Temp. Forest', 'Temp.\nGrassland', 'Trop. Forest','Trop.\nGrassland','Tundra']
#ax.xaxis.set_ticklabels(ticklabels)
ax4.xaxis.label.set_visible(False)
ax4.set_ylim([1.2e13,1.5e19])
#ax.legend(loc = [1.01,0.7])
#ax.ticks
ax4.text(0.01,0.91,'D',fontdict={'size':20},transform = ax4.transAxes)

plt.tight_layout()

plt.rcParams.update({'font.size': 10}) #increase the font size here

#plt.savefig('results/fig_tots.svg', dpi=300)
#plt.savefig('results/fig_tots.pdf', dpi=300)##
#plt.savefig('results/fig_tots.png', dpi=300)##

# %% [markdown]
# soil_biome_means_G.reset_index(inplace=True)
# Isoptera_G = soil_biome_means_G[soil_biome_means_G['aggregated taxon']=='Isoptera']
# Isoptera_G.to_csv('results/Isoptera_G.csv')##

# %% [markdown]
# # Sensitivity analysis

# %%
(soil_biome_Mean1.loc[:,'Mean_Ar']*soil_biome_Mean1.loc[:,'area']).values.sum()/1e15 #total population per biome, in units of mg. (use 1e18 to convert to Gt)
# Out:
# 236.96686698499505

# %%
#The mean using bootstrapping is slightly larger due to the inclusion of errors, being non-symmetric due to the positivity of the biomass
(soil_biome_Mean2.loc[:,'mean']*soil_biome_Mean2.loc[:,'area']).values.sum()/1e15 #total population per biome, in units of mg. (use 1e18 to convert to Gt)
# Out:
# 238.47110296920667

# %%
N = len(soil_site_data_mass_all)
N_range = np.arange(0, N, 1)
SSd = soil_site_data_mass_all.loc[:,['aggregated taxon','aggregated biome','mass_G']]

tot_soil_sens=np.zeros(N)

for ii in N_range:
    soil_biome_means_G_sens = SSd.loc[N_range!=ii].groupby(['aggregated taxon','aggregated biome'])['mass_G'].agg([calc_mean_ar])
    soil_biome_means_G_sens.rename(columns={'calc_mean_ar': 'Mean_Ar'}, inplace=True)
                          
    soil_biome_Mean_sens = soil_biome_means_G_sens.merge(pd.DataFrame(biome_area1),left_on='aggregated biome',right_index=True) 
    tot_soil_sens[ii] = (soil_biome_Mean_sens.loc[:,'Mean_Ar']*soil_biome_Mean_sens.loc[:,'area']).values.sum()/1e15 #total population per biome, in units of mg. (use 1e18 to convert to

plt.hist(tot_soil_sens,40)

#Removing a single site can result in up to 3% change in the final evaluation for soils
print('extreme upper change: ' + '{:.1f}'.format(100*(np.max(tot_soil_sens)-np.mean(tot_soil_sens))/np.mean(tot_soil_sens)) + '%')
print('extreme lower change: ' + '{:.1f}'.format(100*(np.mean(tot_soil_sens)-np.min(tot_soil_sens))/np.mean(tot_soil_sens)) + '%')
# Out:
# extreme upper change: 1.6%
# extreme lower change: 2.9%

# %%
def filter_outliers(x):
    if len(x)>3:
        STD=x.std()
        Mean=np.mean(x)
        x = x[x<(Mean+3*STD)]
        x = x[x>(Mean-3*STD)]
    return x

def filter_outliers_log(x):
    if len(x)>3:
        X = np.log(x+0.01)
        STD=X.std()
        Mean=np.mean(X)
        x = x[X<(Mean+2*STD)]
        x = x[X>(Mean-2*STD)]
    return x

def filt_mean(x):
    return calc_mean_ar(filter_outliers_log(x))

soil_biome_means_G_outliers = SSd.groupby(['aggregated taxon','aggregated biome'])['mass_G'].agg([filt_mean])
soil_biome_means_G_outliers.rename(columns={'filt_mean': 'Mean_Ar'}, inplace=True)
soil_biome_Mean_outliers = soil_biome_means_G_outliers.merge(pd.DataFrame(biome_area1),left_on='aggregated biome',right_index=True) 
tot_soil_outliers = (soil_biome_Mean_outliers.loc[:,'Mean_Ar']*soil_biome_Mean_outliers.loc[:,'area']).values.sum()/1e15 #total population per biome, in units of mg.

tot_soil_outliers
# Out:
# 226.07726638130362

# %%
def filter_outliers(x):
    if len(x)>3:
        STD=x.std()
        Mean=np.mean(x)
        x = x[x<(Mean+2*STD)]
        x = x[x>(Mean-2*STD)]
    return x

def filt_mean(x):
    return calc_mean_ar(filter_outliers(x))

soil_biome_means_G_outliers = SSd.groupby(['aggregated taxon','aggregated biome'])['mass_G'].agg([filt_mean])
soil_biome_means_G_outliers.rename(columns={'filt_mean': 'Mean_Ar'}, inplace=True)
soil_biome_Mean_outliers = soil_biome_means_G_outliers.merge(pd.DataFrame(biome_area1),left_on='aggregated biome',right_index=True) 
tot_soil_outliers = (soil_biome_Mean_outliers.loc[:,'Mean_Ar']*soil_biome_Mean_outliers.loc[:,'area']).values.sum()/1e15 #total population per biome, in units of mg.

tot_soil_outliers
# Out:
# 166.18125090546246

# %%
#166 with 2STD linear space
#226 with 2 STD in log space, similar to the case of dropping a single site
